# %%
import gzip
import bz2
import pickle
from nltk.stem import SnowballStemmer
from nltk.corpus import stopwords
from nltk import ngrams
from pymystem3 import Mystem
import re
from collections import Counter

# %%
from joblib import Parallel, delayed

# %%
import os

# %%
from tqdm import tqdm

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
import numpy as np

# %%
#calculating TF

# %%
def process(idx, title, text):
    if os.path.exists('./data/' + idx + '.text'):
        return
    
    text = ' '.join(lemmatizer.lemmatize(text.lower()))
    title = ' '.join(lemmatizer.lemmatize(title.lower()))
    
    with open('./data/' + idx + '.text', 'wb') as fout:
        counts = Counter(pattern.findall(text))
        pickle.dump(counts, fout)
    with open('./data/' + idx + '.title', 'wb') as fout:
        counts = Counter(pattern.findall(title))
        pickle.dump(counts, fout)

# %%
# stemmer = SnowballStemmer('russian', ignore_stopwords=True)
cnt = 0
n_threads = 32
lemmatizer = Mystem()
pattern = re.compile('\d+|[^\W\d]+')

# %%
with gzip.open('./docs.tsv.gz', 'rb') as f:
    params = [('', '', '') for i in range(n_threads)]
    for line in f:
        if cnt != 0 and cnt % n_threads == 0:
            Parallel(n_jobs=n_threads)(delayed(process)(*params[j]) for j in range(n_threads))

        idx, title, text = line.decode('utf-8').split('\t')
        params[cnt % n_threads] = (idx, title, text)
        cnt += 1

# %%
#count files length

# %%
pattern = re.compile('\d+|[^\W\d]+')

# %%
title_lengths = dict()
text_lengths = dict()

# %%
with open('lengths.title', 'r') as fin:
    for line in fin:
        spl = line.strip().split(' ')
        title_lengths[spl[0]] = int(spl[2])

# %%
sum(title_lengths.values()) / len(title_lengths)
# Out:
# 8.3285758210273

# %%
with open('lengths.text', 'r') as fin:
    for line in fin:
        spl = line.strip().split(' ')
        text_lengths[spl[0]] = int(spl[2])

# %%
sum(text_lengths.values()) / len(title_lengths)
# Out:
# 9717.212767126959

# %%
with open('./lengths.title', 'wb') as fout:
    pickle.dump(title_lengths, fout)

# %%
with open('./lengths.text', 'wb') as fout:
    pickle.dump(text_lengths, fout)

# %%
#removing numbers of 5+ digits

# %%
files = os.listdir('./data')
n_threads = 8
per = len(files) // n_threads + 1

# %%
dpattern = re.compile('\d{5}\d*')

# %%
def process1(idx, fnames):
    for fname, cnt in zip(fnames, range(len(fnames))):
        if (cnt + 1) % 15000 == 0:
            print(idx, 'finished', cnt)
        dc = {}
        with open('./data/' + fname, 'rb') as fin:
            dc = pickle.load(fin)
            
        ndc = dict(filter(lambda x: not dpattern.match(x[0]), dc.items()))
        with open('./data/' + fname, 'wb') as fout:
            pickle.dump(ndc, fout)

# %%
Parallel(n_jobs=n_threads)(delayed(process1)(j, files[j*per : (j+1)*per]) for j in range(n_threads))
# Out:
# 0 finished 14999
# 0 finished 29999
# 6 finished 14999
# 1 finished 14999
# 2 finished 14999
# 7 finished 14999
# 4 finished 14999
# 3 finished 14999
# 5 finished 14999
# 0 finished 44999
# 6 finished 29999
# 4 finished 29999
# 1 finished 29999
# 3 finished 29999
# 2 finished 29999
# 7 finished 29999
# 5 finished 29999
# 0 finished 59999
# 6 finished 44999
# 1 finished 44999
# 7 finished 44999
# 2 finished 44999
# 4 finished 44999
# 3 finished 44999
# 5 finished 44999
# 0 finished 74999
# 6 finished 59999
# 1 finished 59999
# 7 finished 59999
# 2 finished 59999
# 4 finished 59999
# 3 finished 59999
# 5 finished 59999
# 0 finished 89999

# %%
#stemming and filter stopwords

# %%
stemmer = SnowballStemmer('russian', ignore_stopwords=True)
stop = stopwords.words('russian')

# %%
def process2(idx, fnames):
    for fname, cnt in zip(fnames, range(len(fnames))):
        if (cnt + 1) % 15000 == 0:
            print(idx, 'finished', cnt)
        dc = {}
        with open('./data/' + fname, 'rb') as fin:
            dc = pickle.load(fin)

        ndc = filter(lambda x: not (x[0] in stop), dc.items())
        ndc = dict(map(lambda x: (stemmer.stem(x[0]), x[1]), ndc))
        with open('./data/' + fname, 'wb') as fout:
            pickle.dump(ndc, fout)

# %%
Parallel(n_jobs=n_threads)(delayed(process2)(j, files[j*per : (j+1)*per]) for j in range(n_threads))
# Out:
# 0 finished 14999
# 1 finished 14999
# 6 finished 14999
# 2 finished 14999
# 7 finished 14999
# 3 finished 14999
# 4 finished 14999
# 5 finished 14999
# 0 finished 29999
# 6 finished 29999
# 1 finished 29999
# 4 finished 29999
# 3 finished 29999
# 2 finished 29999
# 7 finished 29999
# 5 finished 29999
# 0 finished 44999
# 6 finished 44999
# 1 finished 44999
# 7 finished 44999
# 2 finished 44999
# 4 finished 44999
# 3 finished 44999
# 5 finished 44999
# 0 finished 59999
# 6 finished 59999
# 1 finished 59999
# 7 finished 59999
# 2 finished 59999
# 4 finished 59999
# 3 finished 59999
# 5 finished 59999
# 0 finished 74999
# 6 finished 74999
# 1 finished 74999
# 7 finished 74999
# 2 finished 74999
# 4 finished 74999
# 3 finished 74999
# 5 finished 74999
# 0 finished 89999
# 6 finished 89999
# 7 finished 89999
# 2 finished 89999
# 3 finished 89999
# 1 finished 89999
# 4 finished 89999
# 5 finished 89999
# 0 finished 104999
# 6 finished 104999
# 2 finished 104999
# 3 finished 104999
# 7 finished 104999
# 4 finished 104999
# 1 finished 104999
# 5 finished 104999
# 0 finished 119999

# %%
! echo 'hello' > log.txt

# %%
#fix queries layout

# %%
_eng_chars = u"~!@#$%^&qwertyuiop[]asdfghjkl;'zxcvbnm,./QWERTYUIOP{}ASDFGHJKL:\"|ZXCVBNM<>?"
_rus_chars = u"ё!\"№;%:?йцукенгшщзхъфывапролджэячсмитьбю.ЙЦУКЕНГШЩЗХЪФЫВАПРОЛДЖЭ/ЯЧСМИТЬБЮ,"
_trans_table = dict(zip(_eng_chars, _rus_chars))
 
def fix_layout(s):
    return u''.join([_trans_table.get(c, c) for c in s])

# %%
#partial words set
ds = set()
for f in tqdm(os.listdir('./data')[0:60000]):
    with open('./data/' + f, 'rb') as fin:
        ds.update(pickle.load(fin).keys())
# Out:
# 100%|██████████| 60000/60000 [00:25<00:00, 2399.78it/s]

# %%
enw = re.compile('^[a-zA-Z]+$')
def fix(s):
    if not enw.match(s):
        return s
    fx = stemmer.stem(lemmatizer.lemmatize(fix_layout(s))[0])
    
    if (fx in ds) or fix_layout(s) in stop:
        return fix_layout(s)
    
    return s

# %%
fout = open('./queries.fix', 'w')

# %%
with open('./queries.tsv', 'r') as fin:
    for line in fin:
        idx, line = line.split('\t')
        words = pattern.findall(line)
        res = ' '.join([fix(word) for word in words])
        fout.write(idx + '\t' + res + '\n')

# %%
fout.close()

# %%
# create total words dict

# %%
def processd(idx, fnames):
    cnt = 0
    df = Counter()
    buf = Counter()
    for fname, cnt in zip(fnames, range(len(fnames))):
        if (cnt + 1) % 1000 == 0:
            df += buf
            buf.clear()
            
        if (cnt + 1) % 5000 == 0:
            print(idx, 'finished', cnt)
        
        pr = Counter()
        with open('./data/' + fname, 'rb') as fin:
            pr = Counter(pickle.load(fin))
        buf += pr
    df += buf
    with open(str(idx) + '.dict', 'wb') as fout:
        pickle.dump(df, fout)

# %%
files = os.listdir('./data')
n_threads = 30
per = len(files) // n_threads + 1

# %%
Parallel(n_jobs=n_threads)(delayed(processd)(j, files[j*per : (j+1)*per]) for j in range(n_threads))
# Out:
# 14 finished 4999
# 28 finished 4999
# 6 finished 4999
# 2 finished 4999
# 11 finished 4999
# 27 finished 4999
# 26 finished 4999
# 4 finished 4999
# 8 finished 4999
# 0 finished 4999
# 25 finished 4999
# 23 finished 4999
# 13 finished 4999
# 19 finished 4999
# 16 finished 4999
# 10 finished 4999
# 5 finished 4999
# 3 finished 4999
# 15 finished 4999
# 17 finished 4999
# 20 finished 4999
# 29 finished 4999
# 21 finished 4999
# 18 finished 4999
# 12 finished 4999
# 9 finished 4999
# 24 finished 4999
# 7 finished 4999
# 22 finished 4999
# 1 finished 4999
# 14 finished 9999
# 27 finished 9999
# 6 finished 9999
# 11 finished 9999
# 10 finished 9999
# 13 finished 9999
# 25 finished 9999
# 4 finished 9999
# 0 finished 9999
# 29 finished 9999
# 24 finished 9999
# 2 finished 9999
# 3 finished 9999
# 28 finished 9999
# 8 finished 9999
# 26 finished 9999
# 7 finished 9999
# 9 finished 9999
# 18 finished 9999
# 19 finished 9999
# 20 finished 9999
# 1 finished 9999
# 21 finished 9999
# 15 finished 9999
# 17 finished 9999
# 23 finished 9999
# 22 finished 9999
# 12 finished 9999
# 5 finished 9999
# 16 finished 9999
# 14 finished 14999
# 27 finished 14999
# 11 finished 14999
# 0 finished 14999
# 10 finished 14999
# 3 finished 14999
# 6 finished 14999
# 29 finished 14999
# 13 finished 14999
# 2 finished 14999
# 4 finished 14999
# 25 finished 14999
# 24 finished 14999
# 16 finished 14999
# 28 finished 14999
# 8 finished 14999
# 1 finished 14999
# 9 finished 14999
# 26 finished 14999
# 15 finished 14999
# 17 finished 14999
# 19 finished 14999
# 23 finished 14999
# 7 finished 14999
# 20 finished 14999
# 12 finished 14999
# 5 finished 14999
# 21 finished 14999
# 18 finished 14999
# 22 finished 14999
# 0 finished 19999
# 1 finished 19999
# 1 finished 24999
# 0 finished 24999
# 14 finished 19999
# 11 finished 19999
# 2 finished 19999
# 27 finished 19999
# 3 finished 19999
# 28 finished 19999
# 13 finished 19999
# 10 finished 19999
# 4 finished 19999
# 1 finished 29999
# 16 finished 19999
# 25 finished 19999
# 29 finished 19999
# 0 finished 29999
# 24 finished 19999
# 8 finished 19999
# 23 finished 19999
# 9 finished 19999
# 6 finished 19999
# 17 finished 19999
# 5 finished 19999
# 26 finished 19999
# 12 finished 19999
# 19 finished 19999
# 7 finished 19999
# 15 finished 19999
# 20 finished 19999
# 18 finished 19999
# 21 finished 19999
# 22 finished 19999
# 0 finished 34999
# 14 finished 24999
# 2 finished 24999
# 11 finished 24999
# 1 finished 34999
# 27 finished 24999
# 28 finished 24999
# 25 finished 24999
# 10 finished 24999
# 3 finished 24999
# 4 finished 24999
# 9 finished 24999
# 16 finished 24999
# 29 finished 24999
# 23 finished 24999
# 8 finished 24999
# 24 finished 24999
# 13 finished 24999
# 6 finished 24999
# 5 finished 24999
# 19 finished 24999
# 17 finished 24999
# 20 finished 24999
# 15 finished 24999
# 26 finished 24999
# 21 finished 24999
# 12 finished 24999
# 7 finished 24999
# 22 finished 24999
# 18 finished 24999
# 2 finished 29999
# 14 finished 29999
# 27 finished 29999
# 28 finished 29999
# 11 finished 29999
# 4 finished 29999
# 16 finished 29999
# 10 finished 29999
# 25 finished 29999
# 9 finished 29999
# 13 finished 29999
# 3 finished 29999
# 24 finished 29999
# 5 finished 29999
# 29 finished 29999
# 23 finished 29999
# 8 finished 29999
# 20 finished 29999
# 6 finished 29999
# 17 finished 29999
# 7 finished 29999
# 21 finished 29999
# 19 finished 29999
# 22 finished 29999
# 15 finished 29999
# 26 finished 29999
# 12 finished 29999
# 18 finished 29999
# 14 finished 34999
# 2 finished 34999
# 11 finished 34999
# 27 finished 34999
# 16 finished 34999
# 4 finished 34999
# 10 finished 34999
# 9 finished 34999
# 28 finished 34999
# 3 finished 34999
# 23 finished 34999
# 25 finished 34999
# 13 finished 34999
# 29 finished 34999
# 24 finished 34999
# 6 finished 34999
# 8 finished 34999
# 20 finished 34999
# 5 finished 34999
# 7 finished 34999
# 17 finished 34999
# 22 finished 34999
# 19 finished 34999
# 26 finished 34999
# 21 finished 34999
# 12 finished 34999
# 15 finished 34999
# 18 finished 34999
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %%
df = Counter()
for i in range(30):
    with open(str(i) + '.dict', 'rb') as fin:
        df += pickle.load(fin)

# %%
df.pop('')
with open('./total.dict', 'wb') as fout:
    pickle.dump(df, fout)

# %%
# tf and df for query words

# %%
qw = set()
with open('queries.final', 'r') as fin:
    for line in fin:
        idx, line = line.split('\t')
        words = pattern.findall(line)
        for word in words:
            w = stemmer.stem(lemmatizer.lemmatize(word)[0])
            qw.add(w)

# %%
len(qw)
# Out:
# 8922

# %%
totalf = dict()
with open('total.dict', 'rb') as fin:
    totalf = pickle.load(fin)

# %%
qw2 = set()
for w in qw:
    if not (w in totalf):
        continue
    qw2.add(w)
qw = qw2

# %%
len(qw)
# Out:
# 8895

# %%
titlefiles = !ls ./data | grep '\.title'
textfiles = !ls ./data | grep '\.text'

# %%
def processF(idx, fnames):
    for fname, cnt in zip(fnames, range(len(fnames))):
        if (cnt + 1) % 10000 == 0:
            print(idx, 'finished', cnt)
        
        if os.path.exists('./frequences/' + fname):
            continue
        
        dc = {}
        with open('./data/' + fname, 'rb') as fin:
            dc = pickle.load(fin)
        dc = dict(list(filter(lambda x: x[0] in qw, dc.items())))
        with open('./frequences/' + fname, 'wb') as fout:
            pickle.dump(dc, fout)

# %%
n_threads = 8
per = len(titlefiles) // n_threads + 1

# %%
Parallel(n_jobs=n_threads)(delayed(processF)(j, titlefiles[j*per : (j+1)*per]) for j in range(n_threads))
# Out:
# 0 finished 9999
# 0 finished 19999
# 2 finished 9999
# 7 finished 9999
# 3 finished 9999
# 4 finished 9999
# 1 finished 9999
# 6 finished 9999
# 5 finished 9999
# 0 finished 29999
# 2 finished 19999
# 7 finished 19999
# 3 finished 19999
# 4 finished 19999
# 5 finished 19999
# 1 finished 19999
# 6 finished 19999
# 0 finished 39999
# 7 finished 29999
# 2 finished 29999
# 6 finished 29999
# 4 finished 29999
# 3 finished 29999
# 5 finished 29999
# 1 finished 29999
# 0 finished 49999
# 7 finished 39999
# 2 finished 39999
# 6 finished 39999
# 4 finished 39999
# 5 finished 39999
# 3 finished 39999
# 1 finished 39999
# 0 finished 59999
# 7 finished 49999
# 2 finished 49999
# 5 finished 49999
# 6 finished 49999
# 4 finished 49999
# 1 finished 49999
# 3 finished 49999
# 0 finished 69999
# 7 finished 59999
# 5 finished 59999
# 2 finished 59999
# 4 finished 59999
# 6 finished 59999
# 1 finished 59999
# 3 finished 59999
# 5 finished 69999
# 6 finished 69999
# 7 finished 69999
# 4 finished 69999
# 2 finished 69999
# 1 finished 69999
# 3 finished 69999
# [None, None, None, None, None, None, None, None]

# %%
Parallel(n_jobs=n_threads)(delayed(processF)(j, textfiles[j*per : (j+1)*per]) for j in range(n_threads))
# Out:
# 3 finished 9999
# 6 finished 9999
# 2 finished 9999
# 0 finished 9999
# 7 finished 9999
# 5 finished 9999
# 1 finished 9999
# 4 finished 9999
# 6 finished 19999
# 7 finished 19999
# 2 finished 19999
# 0 finished 19999
# 3 finished 19999
# 1 finished 19999
# 5 finished 19999
# 4 finished 19999
# 6 finished 29999
# 7 finished 29999
# 2 finished 29999
# 0 finished 29999
# 1 finished 29999
# 3 finished 29999
# 5 finished 29999
# 7 finished 39999
# 4 finished 29999
# 6 finished 39999
# 2 finished 39999
# 0 finished 39999
# 1 finished 39999
# 5 finished 39999
# 3 finished 39999
# 6 finished 49999
# 7 finished 49999
# 4 finished 39999
# 2 finished 49999
# 3 finished 49999
# 0 finished 49999
# 5 finished 49999
# 1 finished 49999
# 6 finished 59999
# 7 finished 59999
# 2 finished 59999
# 4 finished 49999
# 3 finished 59999
# 0 finished 59999
# 5 finished 59999
# 1 finished 59999
# 2 finished 69999
# 6 finished 69999
# 7 finished 69999
# 4 finished 59999
# 0 finished 69999
# 3 finished 69999
# 5 finished 69999
# 1 finished 69999
# 4 finished 69999
# [None, None, None, None, None, None, None, None]

# %%
title_df = Counter()
text_df = Counter()

# %%
def processDF(idx, fnames):
    df = Counter()
    for fname, cnt in zip(fnames, range(len(fnames))):
        if (cnt + 1) % 10000 == 0:
            print(idx, 'finished', cnt+1)
            
        with open('./frequences/' + fname, 'rb') as fin:
            df.update(pickle.load(fin).keys())
    
    return df

# %%
n_threads = 8
per = len(textfiles) // n_threads + 1

# %%
title_dfs = Parallel(n_jobs=n_threads)(delayed(processDF)(j, titlefiles[j*per : (j+1)*per]) for j in range(n_threads))
# Out:
# 1 finished 10000
# 0 finished 10000
# 2 finished 10000
# 3 finished 10000
# 4 finished 10000
# 7 finished 10000
# 6 finished 10000
# 5 finished 10000
# 2 finished 20000
# 1 finished 20000
# 0 finished 20000
# 3 finished 20000
# 7 finished 20000
# 4 finished 20000
# 6 finished 20000
# 5 finished 20000
# 2 finished 30000
# 1 finished 30000
# 0 finished 30000
# 3 finished 30000
# 7 finished 30000
# 4 finished 30000
# 6 finished 30000
# 5 finished 30000
# 2 finished 40000
# 1 finished 40000
# 3 finished 40000
# 0 finished 40000
# 7 finished 40000
# 4 finished 40000
# 6 finished 40000
# 5 finished 40000
# 2 finished 50000
# 1 finished 50000
# 3 finished 50000
# 0 finished 50000
# 7 finished 50000
# 4 finished 50000
# 6 finished 50000
# 5 finished 50000
# 2 finished 60000
# 1 finished 60000
# 3 finished 60000
# 0 finished 60000
# 7 finished 60000
# 4 finished 60000
# 6 finished 60000
# 5 finished 60000
# 1 finished 70000
# 2 finished 70000
# 0 finished 70000
# 3 finished 70000
# 7 finished 70000
# 5 finished 70000
# 4 finished 70000
# 6 finished 70000

# %%
for df in title_dfs:
    title_df += df

# %%
with open('./title.df', 'wb') as fout:
    pickle.dump(title_df, fout)

# %%
text_dfs = Parallel(n_jobs=n_threads)(delayed(processDF)(j, textfiles[j*per : (j+1)*per]) for j in range(n_threads))
# Out:
# 2 finished 10000
# 6 finished 10000
# 0 finished 10000
# 2 finished 20000
# 6 finished 20000
# 4 finished 10000
# 0 finished 20000
# 3 finished 10000
# 7 finished 10000
# 5 finished 10000
# 1 finished 10000
# 4 finished 20000
# 7 finished 20000
# 3 finished 20000
# 1 finished 20000
# 5 finished 20000
# 6 finished 30000
# 2 finished 30000
# 0 finished 30000
# 7 finished 30000
# 1 finished 30000
# 3 finished 30000
# 5 finished 30000
# 7 finished 40000
# 4 finished 30000
# 6 finished 40000
# 2 finished 40000
# 0 finished 40000
# 1 finished 40000
# 5 finished 40000
# 3 finished 40000
# 6 finished 50000
# 7 finished 50000
# 4 finished 40000
# 2 finished 50000
# 3 finished 50000
# 0 finished 50000
# 5 finished 50000
# 1 finished 50000
# 6 finished 60000
# 7 finished 60000
# 2 finished 60000
# 4 finished 50000
# 3 finished 60000
# 0 finished 60000
# 5 finished 60000
# 1 finished 60000
# 2 finished 70000
# 6 finished 70000
# 7 finished 70000
# 4 finished 60000
# 0 finished 70000
# 3 finished 70000
# 5 finished 70000
# 1 finished 70000
# 4 finished 70000

# %%
for df in text_dfs:
    text_df += df

# %%
with open('./text.df', 'wb') as fout:
    pickle.dump(text_df, fout)

# %%
#total document frequency (no dependency on zone)

# %%
def processTDF(idx, fnames):
    df = Counter()
    for fname, cnt in zip(fnames, range(len(fnames))):
        if (cnt + 1) % 10000 == 0:
            print(idx, 'finished', cnt+1)
            
        doc_idx = fname.split('.')[0]
        
        ks1 = []
        ks2 = []
        with open('./frequences/' + doc_idx + '.title', 'rb') as fin:
            ks1 = pickle.load(fin).keys()
        with open('./frequences/' + doc_idx + '.text', 'rb') as fin:
            ks2 = pickle.load(fin).keys()

        df.update(set(ks1) | set(ks2))
    
    return df

# %%
n_threads = 8
per = len(textfiles) // n_threads + 1

# %%
total_dfs = Parallel(n_jobs=n_threads)(delayed(processTDF)(j, textfiles[j*per : (j+1)*per]) for j in range(n_threads))
# Out:
# 3 finished 10000
# 6 finished 10000
# 2 finished 10000
# 0 finished 10000
# 7 finished 10000
# 5 finished 10000
# 1 finished 10000
# 4 finished 10000
# 6 finished 20000
# 7 finished 20000
# 2 finished 20000
# 0 finished 20000
# 3 finished 20000
# 1 finished 20000
# 5 finished 20000
# 4 finished 20000
# 6 finished 30000
# 7 finished 30000
# 2 finished 30000
# 0 finished 30000
# 1 finished 30000
# 3 finished 30000
# 5 finished 30000
# 4 finished 30000
# 7 finished 40000
# 6 finished 40000
# 2 finished 40000
# 0 finished 40000
# 1 finished 40000
# 5 finished 40000
# 3 finished 40000
# 6 finished 50000
# 7 finished 50000
# 4 finished 40000
# 2 finished 50000
# 3 finished 50000
# 0 finished 50000
# 5 finished 50000
# 1 finished 50000
# 6 finished 60000
# 7 finished 60000
# 2 finished 60000
# 4 finished 50000
# 3 finished 60000
# 0 finished 60000
# 5 finished 60000
# 1 finished 60000
# 2 finished 70000
# 6 finished 70000
# 7 finished 70000
# 4 finished 60000
# 0 finished 70000
# 3 finished 70000
# 5 finished 70000
# 1 finished 70000
# 4 finished 70000

# %%
total_df = Counter()

# %%
for df in total_dfs:
    total_df += df

# %%
with open('./total.df', 'wb') as fout:
    pickle.dump(total_df, fout)

# %%
len(total_df)
# Out:
# 8895

# %%
# create 3-gramms dictionary for DSSM

# %%
pattern = re.compile('\d+|[^\W\d]+')

# %%
d3 = Counter()

# %%
cnt = 0
with open('titles.txt', 'r') as fin:
    for line in fin:
        cnt += 1
        
        if cnt % 20000 == 0:
            print('processed', cnt)
        
        title = line.split('\t')[1].lower()
        title = '#' + '#'.join(pattern.findall(title)) + '#'
        gg = filter(lambda x: x[1] != '#', ngrams(list(title), 3))
        grams3 = map(lambda x: ''.join(x), gg)
        d3.update(grams3)
# Out:
# processed 20000
# processed 40000
# processed 60000
# processed 80000
# processed 100000
# processed 120000
# processed 140000
# processed 160000
# processed 180000
# processed 200000
# processed 220000
# processed 240000
# processed 260000
# processed 280000
# processed 300000
# processed 320000
# processed 340000
# processed 360000
# processed 380000
# processed 400000
# processed 420000
# processed 440000
# processed 460000
# processed 480000
# processed 500000
# processed 520000
# processed 540000
# processed 560000
# processed 580000

# %%
len(d3)
# Out:
# 42365

# %%
d3.most_common()[0:10]
# Out:
# [('ть#', 186925),
#  ('#по', 168149),
#  ('#пр', 152950),
#  ('#на', 139423),
#  ('#ка', 138145),
#  ('на#', 130092),
#  ('ия#', 126663),
#  ('#в#', 125282),
#  ('ие#', 118564),
#  ('ени', 118020)]

# %%
list(filter(lambda x: ' ' in x , list(d3.keys())))
# Out:
# []

# %%
with open('3gramms.dict', 'wb') as fout:
    pickle.dump(d3, fout)

# %%
def process3G(idx, files):
    d3g = Counter()
    for fname, cnt in zip(files, range(len(files))):
        with bz2.BZ2File('./clicks/2017/' + fname, 'r') as fin:
            for line in fin:
                text = line.decode('utf-8').split('@')[0].lower()
                text = '#' + '#'.join(pattern.findall(text)) + '#'
                gg = filter(lambda x: x[1] != '#', ngrams(list(text), 3))
                grams3 = map(lambda x: ''.join(x), gg)
                d3g.update(grams3)
        if (cnt + 1) % 10 == 0:
            print(idx, 'processed', cnt)
            
    return d3g

# %%
files = os.listdir('clicks/2017/')
n_threads = 32
per = len(files) // n_threads + 1

# %%
d3gs = Parallel(n_jobs=n_threads)(delayed(process3G)(j, files[j*per : (j+1)*per]) for j in range(n_threads))
# Out:
# 26 processed 9
# 13 processed 9
# 5 processed 9
# 21 processed 9
# 24 processed 9
# 18 processed 9
# 8 processed 9
# 27 processed 9
# 11 processed 9
# 19 processed 9
# 16 processed 9
# 10 processed 9
# 15 processed 9
# 23 processed 9
# 22 processed 9
# 2 processed 9
# 9 processed 9
# 20 processed 9
# 0 processed 9
# 30 processed 9
# 3 processed 9
# 25 processed 9
# 7 processed 9
# 14 processed 9
# 26 processed 19
# 29 processed 9
# 1 processed 9
# 28 processed 9
# 10 processed 19
# 6 processed 9
# 17 processed 9
# 31 processed 9
# 24 processed 19
# 12 processed 9
# 4 processed 9
# 13 processed 19
# 8 processed 19
# 23 processed 19
# 21 processed 19
# 16 processed 19
# 27 processed 19
# 5 processed 19
# 15 processed 19
# 3 processed 19
# 7 processed 19
# 13 processed 29
# 20 processed 19
# 11 processed 19
# 14 processed 19
# 19 processed 19
# 2 processed 19
# 0 processed 19
# 30 processed 19
# 22 processed 19
# 25 processed 19
# 17 processed 19
# 29 processed 19
# 23 processed 29
# 24 processed 29
# 1 processed 19
# 18 processed 19
# 28 processed 19
# 6 processed 19
# 4 processed 19
# 21 processed 29
# 15 processed 29
# 26 processed 29
# 16 processed 29
# 5 processed 29
# 19 processed 29
# 14 processed 29
# 10 processed 29
# 9 processed 19
# 31 processed 19
# 8 processed 29
# 7 processed 29
# 27 processed 29
# 12 processed 19
# 17 processed 29
# 18 processed 29
# 20 processed 29
# 13 processed 39
# 21 processed 39
# 25 processed 29
# 28 processed 29
# 15 processed 39
# 12 processed 29
# 22 processed 29
# 2 processed 29
# 1 processed 29
# 16 processed 39
# 11 processed 29
# 30 processed 29
# 17 processed 39
# 0 processed 29
# 26 processed 39
# 19 processed 39
# 10 processed 39
# 6 processed 29
# 24 processed 39
# 5 processed 39
# 7 processed 39
# 29 processed 29
# 31 processed 29
# 27 processed 39
# 4 processed 29
# 20 processed 39
# 28 processed 39
# 13 processed 49
# 3 processed 29
# 9 processed 29
# 8 processed 39
# 12 processed 39
# 24 processed 49
# 14 processed 39
# 16 processed 49
# 23 processed 39
# 15 processed 49
# 17 processed 49
# 4 processed 39
# 3 processed 39
# 2 processed 39
# 7 processed 49
# 22 processed 39
# 25 processed 39
# 21 processed 49
# 18 processed 39
# 30 processed 39
# 11 processed 39
# 27 processed 49
# 12 processed 49
# 9 processed 39
# 29 processed 39
# 19 processed 49
# 7 processed 59
# 13 processed 59
# 24 processed 59
# 16 processed 59
# 28 processed 49
# 5 processed 49
# 20 processed 49
# 31 processed 39
# 0 processed 39
# 21 processed 59
# 10 processed 49
# 1 processed 39
# 15 processed 59
# 25 processed 49
# 6 processed 39
# 4 processed 49
# 26 processed 49
# 17 processed 59
# 8 processed 49
# 18 processed 49
# 12 processed 59
# 23 processed 49
# 9 processed 49
# 30 processed 49
# 2 processed 49
# 14 processed 49
# 3 processed 49
# 5 processed 59
# 6 processed 49
# 29 processed 49
# 20 processed 59
# 22 processed 49
# 27 processed 59
# 25 processed 59
# 19 processed 59
# 26 processed 59
# 0 processed 49
# 18 processed 59
# 28 processed 59
# 4 processed 59
# 23 processed 59
# 9 processed 59
# 2 processed 59
# 3 processed 59
# 8 processed 59
# 1 processed 49
# 11 processed 49
# 10 processed 59
# 30 processed 59
# 6 processed 59
# 29 processed 59
# 22 processed 59
# 0 processed 59
# 14 processed 59
# 11 processed 59
# 1 processed 59

# %%
d3g = Counter()
for d in d3gs:
    d3g += d

# %%
with open('3gramms.dict', 'rb') as fin:
    d3g += pickle.load(fin)

# %%
len(d3g)
# Out:
# 162791

# %%
with open('3gramms-total.dict', 'wb') as fout:
    pickle.dump(d3g, fout)

# %%
d3g.most_common()[85000]
# Out:
# ('ыщё', 10)

# %%
d3g
# Out:
# Counter({'ыgw': 3,
#          'خلك': 6,
#          'لبغ': 10,
#          'gφ#': 29,
#          'гтш': 815,
#          '#чё': 228346,
#          'цёё': 2,
#          'ъмы': 1814,
#          'агь': 449,
#          'еья': 905,
#          '#fу': 72,
#          'єом': 2,
#          'ъжл': 2,
#          'тdx': 2,
#          'akл': 4,
#          'нaк': 88,
#          'imм': 5,
#          'ноk': 141,
#          'shб': 5,
#          'ոկտ': 1,
#          'mqj': 59,
#          'ичу': 13030,
#          'ugs': 888,
#          'gbr': 11710,
#          'ежг': 2359,
#          'kіу': 1,
#          'цяс': 108,
#          'гfy': 11,
#          'jxт': 47,
#          'эдг': 2706,
#          'kvx': 125,
#          'дін': 2165,
#          'цзд': 133,
#          'jjо': 20,
#          'دیگ': 1,
#          'хчч': 9,
#          'зяя': 219,
#          '#ॐd': 1,
#          'tjп': 41,
#          'вчр': 174,
#          'yшe': 5,
#          'բօկ': 1,
#          'hzа': 2,
#          'оs#': 538,
#          'uог': 20,
#          'чgп': 2,
#          'оjm': 2,
#          'іj#': 1,
#          '#ðм': 1,
#          'пел': 698940,
#          'bжж': 1,
#          'хкc': 1,
#          'щбь': 68,
#          'myx': 607,
#          'яwe': 2,
#          'ўрн': 3,
#          'ұза': 99,
#          'фсч': 60,
#          'wыы': 7,
#          'oмн': 27,
#          'уdn': 4,
#          'cqm': 44,
#          'ибp': 2,
#          'tco': 38639,
#          'аbф': 8,
#          '#وم': 32,
#          'վաղ': 2,
#          '#vâ': 1,
#          'ъф#': 26,
#          'bıv': 5,
#          '427': 11078,
#          'жгж': 5,
#          'baм': 12,
#          'офn': 4,
#          'егс': 6178,
#          'юбы': 80875,
#          '#官方': 1,
#          'дча': 2400,
#          'wor': 1215822,
#          '_сб': 3,
#          'мeи': 2,
#          '076': 8037,
#          'lвс': 8,
#          'ınn': 1,
#          'жма': 3538,
#          'роm': 27,
#          'ஐна': 2,
#          'пчэ': 21,
#          'иra': 19,
#          'взґ': 3,
#          '542': 6493,
#          'eдf': 2,
#          'íèê': 2,
#          'лdе': 2,
#          'śӎø': 4,
#          'йrh': 48,
#          'хєш': 19,
#          '中止#': 1,
#          'фэй': 98160,
#          'впн': 28977,
#          'щкп': 8700,
#          'зqi': 2,
#          'uфі': 11,
#          'hap': 11132,
#          '배우#': 1,
#          'dцы': 2,
#          'фli': 5,
#          'րբե': 8,
#          'ілл': 2271,
#          'цьз': 12,
#          'lew': 1827,
#          'эыф': 51,
#          'sси': 39,
#          'цto': 26,
#          'поы': 2808,
#          'wjz': 467,
#          'кох': 39271,
#          'rec': 264167,
#          'oyr': 522,
#          'fku': 17501,
#          'fćh': 1,
#          'eбъ': 2,
#          'bбұ': 2,
#          'мйг': 84,
#          'ояф': 107,
#          'узд': 115945,
#          'ďîč': 1,
#          'ецк': 2412781,
#          'пих': 116223,
#          'vас': 18,
#          'dqw': 109,
#          'nyі': 5,
#          'кcд': 4,
#          'нgp': 2,
#          'яящ': 120,
#          'нy#': 301,
#          'pуr': 4,
#          'ыхж': 704,
#          'кэб': 266,
#          '#тү': 1367,
#          '#26': 184363,
#          'rаr': 26,
#          'lkc': 1629,
#          '硰执㝧': 8,
#          'фщф': 1,
#          'jyp': 501,
#          'tйд': 2,
#          'лиф': 237605,
#          'hеш': 5,
#          'uгп': 2,
#          'hae': 3902,
#          'eэм': 5,
#          'лбн': 7331,
#          'xvl': 234,
#          'яош': 30,
#          'mфи': 245,
#          'цяh': 2,
#          'эюм': 177,
#          'жйк': 24,
#          'кbа': 14,
#          'țhj': 16,
#          'rhw': 212,
#          'дуц': 5483,
#          'nas': 32661,
#          'sщт': 3,
#          '#tй': 5,
#          'влъ': 6,
#          'имn': 9,
#          'кэь': 72,
#          'ххg': 1,
#          'уld': 3,
#          'urо': 11,
#          'еpf': 52,
#          'ътц': 2,
#          '#ÿt': 2,
#          'ьjg': 7,
#          '만나게': 2,
#          'чнi': 55,
#          'зяе': 8505,
#          'へよう': 2,
#          '技发展': 1,
#          'xbо': 12,
#          '潍坊市': 2,
#          'ρίο': 6,
#          'fvв': 19,
#          'itã': 1,
#          'blк': 4,
#          'qbz': 209,
#          'кшм': 3036,
#          'lgф': 2,
#          'fbе': 2,
#          'vgг': 2,
#          'оvi': 96,
#          'упя': 4426,
#          'ъед': 153706,
#          'фмі': 165,
#          'рцs': 9,
#          'hдy': 1,
#          'ruс': 5348,
#          'уеє': 4,
#          'ehd': 1078,
#          'mдз': 5,
#          'ыrd': 2,
#          'lo#': 76552,
#          'kуl': 1,
#          'чoк': 11,
#          'меї': 87,
#          'elr': 4439,
#          'цлт': 111,
#          'єкз': 83,
#          'ěrl': 1,
#          'әһа': 67,
#          'chъ': 1,
#          'өзб': 911,
#          'ыій': 5,
#          'пнс': 5373,
#          'fè#': 4,
#          'iмs': 13,
#          '#аe': 32,
#          'dду': 6,
#          'ггу': 8617,
#          'eзф': 4,
#          '_пс': 5,
#          'пъб': 3,
#          'xlf': 62,
#          'лри': 3332,
#          'jun': 13330,
#          'гnb': 3,
#          'тgf': 18,
#          'ozu': 980,
#          'haз': 3,
#          'وتى': 2,
#          'пiн': 6,
#          'бцх': 10,
#          'рмп': 44442,
#          'èçà': 4,
#          'гур': 769904,
#          'рho': 54,
#          'эпв': 116,
#          'иэд': 282,
#          'lfэ': 1,
#          'ъйх': 5,
#          'დეგ': 3,
#          'нjи': 3,
#          'ыиc': 1,
#          'ａｔｉ': 5,
#          'еol': 2,
#          'егг': 9675,
#          'pоr': 41,
#          '#صف': 8,
#          'լաը': 1,
#          '#пr': 464,
#          'dwk': 41,
#          'аѐс': 2,
#          'wюo': 4,
#          'bго': 68,
#          'ымб': 1679,
#          'огв': 13721,
#          'кmo': 12,
#          'хэъ': 36,
#          'мйю': 11,
#          'лъю': 41,
#          'ыйh': 66,
#          'ﺨﺺ#': 1,
#          'uмх': 2,
#          'vни': 12,
#          '#рќ': 40,
#          'ulн': 1,
#          'ныi': 18,
#          'vже': 4,
#          'xtд': 3,
#          'оеl': 24,
#          'ьnh': 27,
#          'cир': 98,
#          'кхт': 247,
#          'мъя': 35,
#          'ъпщ': 3,
#          'mме': 65,
#          'асz': 3,
#          'тзф': 66,
#          'dhс': 2,
#          'мци': 3000,
#          'vия': 2,
#          'phĭ': 2,
#          'иqс': 10,
#          'ьrh': 53,
#          'куж': 2265,
#          'mлю': 64,
#          '潍坊#': 2,
#          '#ก#': 2,
#          'ыйа': 927,
#          'оъу': 26,
#          '#s¹': 4,
#          'kсн': 1,
#          'ejz': 1440,
#          'чнf': 30,
#          'шші': 5,
#          'งโป': 1,
#          'fmк': 2,
#          'eзі': 2,
#          'т__': 1,
#          'ущг': 786,
#          'eёb': 4,
#          'uej': 183,
#          'لسب': 8,
#          'ecк': 97,
#          'oкy': 4,
#          'зсф': 40,
#          'ueк': 4,
#          '#кÿ': 2,
#          'янe': 39,
#          'iqе': 2,
#          'rzn': 363,
#          'klo': 4499,
#          'фшф': 111,
#          'аеё': 70,
#          'yaq': 320,
#          'афи': 2669297,
#          'ьjr': 6,
#          'naw': 725,
#          'ámo': 1,
#          'ыds': 13,
#          'гэg': 4,
#          'ტიბ': 1,
#          'fər': 1,
#          'ерz': 34,
#          'ery': 41078,
#          'hяж': 2,
#          'флу': 147597,
#          'ггя': 15,
#          'قام': 2,
#          '#jи': 16,
#          'ючp': 2,
#          'фh#': 2,
#          'аgj': 163,
#          'шич': 1556,
#          'гоr': 35,
#          'vыр': 2,
#          'gси': 33,
#          'жүр': 1239,
#          'гоp': 37,
#          'ръё': 16,
#          'доj': 9,
#          'irk': 3963,
#          'ดgt': 1,
#          'cтя': 26,
#          'мдк': 1628,
#          'яыд': 32,
#          'eыt': 6,
#          '合は#': 2,
#          '812': 19981,
#          'шiе': 1,
#          'ljк': 15,
#          'соэ': 133735,
#          'мрь': 1666,
#          'тйл': 294,
#          'олц': 4622,
#          'ņim': 7,
#          'شلق': 6,
#          'čč#': 1,
#          '#қх': 2,
#          'нli': 2,
#          'хiв': 15,
#          'ргк': 1084,
#          'jxе': 18,
#          'pix': 83491,
#          '樂必治': 1,
#          'yло': 11,
#          'дъп': 35,
#          'əді': 4,
#          'ғг#': 2,
#          'йr#': 43,
#          'лaу': 9,
#          'cсі': 2,
#          'رعة': 7,
#          'joс': 3,
#          'ідў': 14,
#          'งดา': 1,
#          'ьвf': 2,
#          'сєю': 2,
#          'жчч': 148,
#          'чві': 10,
#          '#él': 11,
#          'kfф': 4,
#          'жөл': 1,
#          '#eч': 46,
#          'яrs': 3,
#          'hər': 22,
#          'тtv': 55,
#          'лби': 159915,
#          'эўс': 9,
#          'vhj': 2683,
#          'єєр': 33,
#          'аеf': 2,
#          'ｆｏｇ': 2,
#          'ұрқ': 11,
#          'ţen': 6,
#          'odd': 4706,
#          'сvн': 2,
#          'яцг': 20,
#          '#цл': 1706,
#          'امج': 32,
#          'окv': 9,
#          'lxe': 81,
#          'чин': 5241157,
#          'сцу': 1344,
#          'dkw': 91,
#          'ftb': 1060,
#          'мён': 28286,
#          'gta': 262088,
#          'укe': 44,
#          'аьм': 418,
#          'dце': 7,
#          'xри': 13,
#          'jjк': 1,
#          'ефы': 2196,
#          'დი#': 11,
#          'waa': 499,
#          'vян': 115,
#          'онg': 56,
#          '#걸스': 1,
#          'ách': 1,
#          'тbh': 97,
#          'sßε': 8,
#          '#اр': 2,
#          'овp': 44,
#          'ddə': 1,
#          'cii': 7838,
#          '_дв': 1,
#          'kam': 22640,
#          'fюк': 6,
#          'dvu': 460,
#          'yzд': 8,
#          'vоs': 1,
#          'cji': 378,
#          'pеa': 3,
#          'отp': 90,
#          'хjc': 4,
#          'квж': 142,
#          'иmk': 3,
#          'меы': 991,
#          'yум': 2,
#          'iтд': 2,
#          'лov': 6,
#          'jvь': 7,
#          'взв': 14502,
#          'иfn': 19,
#          'йcv': 11,
#          'юзі': 2040,
#          'בול': 7,
#          'kus': 4989,
#          'fod': 713,
#          'hv#': 9847,
#          'уїї': 2,
#          'киэ': 5130,
#          'ixд': 4,
#          'ясҗ': 2,
#          'яqi': 11,
#          'abi': 48393,
#          'ьзя': 227716,
#          'ъэь': 2,
#          'arj': 1879,
#          'эы#': 385,
#          'фвю': 198,
#          'ðеß': 10,
#          'cхe': 4,
#          'xmo': 5957,
#          '#bc': 78510,
#          'тii': 5,
#          'єфл': 2,
#          'tıy': 8,
#          '#өг': 38,
#          'иіб': 4,
#          'bед': 7,
#          'пzn': 6,
#          'mеy': 2,
#          'ёдм': 4,
#          'мрs': 9,
#          'üah': 1,
#          'хнй': 53,
#          'ятү': 2,
#          'їєт': 2,
#          'аог': 7509,
#          'dкъ': 2,
#          'сиv': 63,
#          'umр': 2,
#          'ныt': 442,
#          'пaл': 31,
#          'nrb': 37175,
#          'maм': 9,
#          'xкл': 6,
#          'nh#': 39398,
#          '进行之': 2,
#          'tyл': 4,
#          'cэ#': 28,
#          'qxk': 61,
#          'სტრ': 4,
#          'дpt': 8,
#          'bnl': 492,
#          'йil': 4,
#          '#oq': 555,
#          'tkb': 56367,
#          'hyf': 21794,
#          'даь': 3778,
#          '#δα': 2,
#          'mkу': 3,
#          'дю#': 7711,
#          'run': 55604,
#          'іга': 4669,
#          'өтк': 71,
#          'кёо': 2,
#          'мht': 321,
#          'ncп': 4,
#          'зку': 139120,
#          'qsb': 72,
#          'ююе': 61,
#          'mlv': 56,
#          'рма': 2835611,
#          'эцд': 6,
#          'йсқ': 1,
#          'әр#': 141,
#          'rищ': 5,
#          'ььн': 1672,
#          'ιθν': 2,
#          'нүж': 2,
#          'knэ': 2,
#          'бсё': 7,
#          'lēi': 2,
#          'взй': 14,
#          'онs': 255,
#          'иed': 6,
#          'вhа': 1,
#          'cxи': 2,
#          'mөs': 1,
#          'chr': 724799,
#          'eгы': 2,
#          'зөн': 1,
#          '148': 12847,
#          'юьф': 2311,
#          'wо#': 11,
#          'aьи': 1,
#          'пцп': 76,
#          '#ρл': 7,
#          '#ig': 128423,
#          'ïbi': 1,
#          'azш': 1,
#          'oqh': 8,
#          'қму': 2,
#          '#ðэ': 8,
#          'rип': 6,
#          'лфг': 101,
#          'тшк': 1456,
#          'lбд': 2,
#          'njс': 53,
#          'рўц': 2,
#          'хуя': 7625,
#          'тсз': 517,
#          'ьqj': 1,
#          'гыб': 104,
#          'пкu': 4,
#          'oпл': 62,
#          'oxд': 10,
#          'заl': 19,
#          'tea': 591747,
#          'pлд': 5,
#          'нтж': 460,
#          '对德亦': 2,
#          'mи#': 196,
#          'еʼʼ': 2,
#          'йуо': 118,
#          'qyk': 195,
#          'ыхх': 2593,
#          'яёт': 68,
#          'щлй': 4,
#          'gие': 1,
#          'шфщ': 91,
#          'ожі': 902,
#          'юэъ': 4,
#          '097': 12134,
#          'frö': 2,
#          'ызо': 76506,
#          'йqw': 5,
#          'eсn': 3,
#          'ҷше': 1,
#          'zpc': 47,
#          'éтя': 2,
#          'uyt': 7643,
#          'иbр': 2,
#          'чєж': 2,
#          'наи': 163825,
#          'аєг': 21,
#          'оv#': 379,
#          'どｇ#': 2,
#          '#hі': 2,
#          'nче': 31,
#          'наа': 23378,
#          'rdy': 916,
#          'ыль': 355619,
#          'oxd': 121,
#          'fgь': 1,
#          'азn': 9,
#          'зщэ': 2,
#          'prō': 2,
#          'jkv': 1184,
#          'jyd': 14424,
#          'явп': 193,
#          'анu': 144,
#          'яbi': 8,
#          'ùhu': 1,
#          'фоо': 6998,
#          'dxh': 28,
#          'эбз': 24,
#          'щъ#': 199,
#          'krу': 2,
#          'сби': 293555,
#          'тhи': 10,
#          'スケー': 1,
#          'мыё': 118,
#          'оjn': 49,
#          'хkz': 11,
#          'рйф': 1093,
#          'офб': 566,
#          'жящ': 73,
#          'blм': 2,
#          'ьпт': 10874,
#          'eщ#': 20,
#          'pёт': 2,
#          'äro': 4,
#          'cнэ': 2,
#          'ебт': 4584,
#          'трх': 2398,
#          'yaf': 992,
#          'tno': 71373,
#          'zку': 37,
#          'aзм': 43,
#          'жэё': 4,
#          'сe#': 261,
#          'alo': 790440,
#          'аыh': 1,
#          'огo': 51,
#          'кор': 5612662,
#          'охп': 299,
#          'рёш': 15437,
#          'qnc': 448,
#          'ҳор': 1,
#          'лхн': 293,
#          'кус': 1749418,
#          'yit': 7453,
#          '_hi': 2,
#          'тах': 669526,
#          'yре': 74,
#          '#çт': 34,
#          '#пb': 171,
#          'хгю': 5,
#          'asз': 5,
#          'waю': 5,
#          'мik': 3,
#          'ლარ': 1,
#          'dир': 6,
#          'цки': 1975484,
#          'lсл': 11,
#          'яtr': 9,
#          'южм': 47,
#          'hук': 11,
#          'нў#': 2,
#          'йлъ': 743,
#          'rпт': 2,
#          'оyд': 31,
#          'vеm': 2,
#          'шюз': 6,
#          '#pý': 1,
#          'хкю': 6,
#          'azа': 4,
#          'лбә': 2,
#          'eeг': 8,
#          'мeн': 522,
#          'оьт': 3036,
#          'odв': 1,
#          'иbf': 22,
#          '#تش': 3,
#          'юеэ': 3,
#          'dsc': 22502,
#          'tоs': 12,
#          'иди': 1512927,
#          '#صح': 3,
#          'нық': 237,
#          'omd': 1018,
#          'ორმ': 1,
#          'хөр': 2,
#          'цый': 5304,
#          'sех': 7,
#          'цоз': 64,
#          'boe': 47130,
#          'șki': 2,
#          'var': 55021,
#          'oпщ': 64,
#          'ік#': 36241,
#          'ёдь': 13,
#          'аөф': 4,
#          'мүз': 8,
#          'щa#': 9,
#          'оюк': 772,
#          'tpö': 4,
#          '#бò': 4,
#          '#巨大': 1,
#          'ixc': 354,
#          'ыеы': 890,
#          'ђсњ': 7,
#          'уйс': 56797,
#          'lip': 22679,
#          'o³#': 2,
#          'aнм': 1,
#          '#rī': 9,
#          'алё': 35156,
#          'gin': 251977,
#          'ёве': 2984,
#          'аёд': 81,
#          'cмн': 4,
#          '#nº': 1,
#          'աժո': 1,
#          'гсi': 3,
#          'кrе': 2,
#          'áso': 1,
#          'юуъ': 10,
#          'хвд': 69,
#          'ეე#': 1,
#          'шnd': 10,
#          '#хп': 37729,
#          'вcq': 2,
#          'фжц': 9,
#          '是我的': 1,
#          'вғ#': 3,
#          'зbt': 7,
#          'yhф': 1,
#          'вbr': 55,
#          'спў': 1,
#          'uсa': 4,
#          'hки': 88,
#          'нфн': 1094,
#          'ємю': 2,
#          'мїк': 10,
#          'ตเก': 1,
#          'fèn': 1,
#          'тцф': 114,
#          'идө': 6,
#          'эдщ': 15,
#          '#グラ': 2,
#          'טוט': 1,
#          'хюи': 2,
#          'лк#': 80342,
#          'hбр': 7,
#          'апс': 93169,
#          'рїр': 62,
#          'kmd': 2611,
#          'cдf': 3,
#          'эск': 44583,
#          'үжи': 2,
#          'кчр': 3198,
#          'iрd': 2,
#          'счt': 20,
#          'кхц': 44,
#          'qpi': 42,
#          'пуd': 2,
#          'กมม': 2,
#          '#мn': 379,
#          'aгp': 33,
#          'hfр': 24,
#          'lup': 2127,
#          'ощв': 596,
#          'неa': 33,
#          'ач#': 527337,
#          'ğla': 14,
#          '#щё': 8873,
#          'sió': 10,
#          'طفا': 8,
#          '#án': 4,
#          'тоє': 178,
#          'ияб': 1694,
#          'vge': 2278,
#          '#һв': 2,
#          'ядш': 520,
#          'ьje': 4,
#          'джй': 384,
#          'нq#': 24,
#          'нov': 4,
#          'siн': 2,
#          'аóõ': 1,
#          'icl': 65835,
#          'dпa': 4,
#          'jkç': 2,
#          'vaг': 2,
#          'эвх': 11,
#          'ubы': 4,
#          '#їю': 33,
#          'мюж': 68,
#          'xbь': 2,
#          'тay': 14,
#          'cуp': 1,
#          'eлз': 2,
#          '#ử#': 4,
#          'efa': 5116,
#          'ямг': 316,
#          'σf#': 2,
#          '#уx': 78,
#          'ьss': 25,
#          'қақ': 35,
#          'вhq': 2,
#          'ｍｅ#': 11,
#          'эrt': 1,
#          'uшп': 3,
#          'lpo': 22005,
#          'лeц': 7,
#          'iuq': 70,
#          'եցի': 1,
#          'rād': 4,
#          'fщк': 7,
#          'ыда': 419926,
#          '#fŧ': 2,
#          'ақс': 3392,
#          '#ъе': 145,
#          'rда': 9,
#          'ьйа': 52,
#          '#ჯე': 6,
#          'esö': 2,
#          'огю': 5433,
#          'նաց': 2,
#          'oну': 9,
#          'σɢυ': 2,
#          'یجه': 2,
#          'trq': 350,
#          'фдх': 6,
#          'qот': 17,
#          'уја': 6,
#          'ewy': 393,
#          '#фі': 413353,
#          'ול#': 7,
#          'lст': 31,
#          'sсг': 2,
#          'хпт': 278,
#          'eжч': 6,
#          'чаә': 4,
#          'бнc': 2,
#          'ßcg': 2,
#          '#рэ': 47260,
#          'лл#': 225890,
#          'ъёц': 2,
#          'һвк': 2,
#          'aи#': 34,
#          'сxв': 4,
#          'eîn': 2,
#          'xdq': 34,
#          'гхц': 11,
#          'kмн': 8,
#          'пңд': 2,
#          'xpk': 29,
#          'aгo': 4,
#          'ўкь': 2,
#          'mфа': 18,
#          'hep': 25983,
#          'ดmi': 1,
#          'lıı': 3,
#          'эжя': 6,
#          'аъж': 4,
#          'иғр': 8,
#          'トキラ': 2,
#          'եռս': 1,
#          'диь': 2661,
#          'inв': 71,
#          'пїѕ': 545,
#          'bаt': 5,
#          'pkе': 5,
#          '#k⁵': 2,
#          'куе': 11008,
#          'dyt': 19498,
#          'вei': 35,
#          'ggу': 2,
#          'ьбк': 534,
#          'xbd': 19618,
#          'оті': 4878,
#          'suĺ': 1,
#          'ияе': 75153,
#          'йал': 1888,
#          'хhа': 2,
#          'öf#': 33,
#          'эη#': 2,
#          'ыжb': 2,
#          'očt': 2,
#          'iех': 813,
#          'кмp': 8,
#          'poн': 35,
#          'rьc': 2,
#          'яbc': 2,
#          'оьж': 54,
#          'fдр': 18,
#          'тяр': 10188,
#          '#zв': 99,
#          'ehä': 6,
#          'чxe': 2,
#          'щёх': 2,
#          'дуы': 816,
#          'я_л': 27,
#          '_ас': 1,
#          'լյո': 1,
#          'зюv': 5,
#          'сдш': 1434,
#          '#ım': 17,
#          'ані': 25066,
#          'ᴇs#': 2,
#          'ăfb': 2,
#          'ыbh': 2,
#          'zгу': 20,
#          'кpc': 5,
#          'пti': 2,
#          'hsv': 9591,
#          'nс#': 124,
#          'hxf': 1261,
#          'rxd': 53,
#          'göe': 3,
#          'ржл': 198,
#          'пеg': 5,
#          'гюr': 2,
#          'qst': 349,
#          'iaю': 7,
#          'ébé': 1,
#          'ттi': 25,
#          'mov': 62013,
#          'fhн': 5,
#          'лдъ': 184,
#          'диs': 16,
#          'ӣме': 4,
#          'vhw': 19,
#          'uъ#': 803,
#          'qгв': 5,
#          'пйі': 2,
#          'йbd': 4,
#          'бех': 3475,
#          'wиn': 2,
#          'яэл': 407,
#          'נד#': 2,
#          'вpл': 2,
#          'gис': 28,
#          'еdн': 2,
#          'фши': 493,
#          'heэ': 2,
#          'йムп': 2,
#          'otf': 722,
#          '#оу': 17523,
#          'уyu': 12,
#          'ядn': 2,
#          'dié': 2,
#          'кбь': 174,
#          'jí#': 1,
#          'зыg': 4,
#          'ьюр': 8420,
#          '#ëè': 1,
#          'гал': 1432545,
#          '#პრ': 9,
#          'lдр': 341,
#          'мcо': 5,
#          'wab': 1134,
#          'tбу': 34,
#          'eчь': 9,
#          'してや': 2,
#          'ася': 111445,
#          '杜克#': 4,
#          'גר#': 2,
#          'bся': 2,
#          'бhе': 2,
#          '捥㬩慢': 16,
#          'ад#': 1587914,
#          'մոտ': 5,
#          'koe': 57633,
#          'orq': 1871,
#          'онқ': 8,
#          'qfr': 105,
#          'vti': 22717,
#          'оht': 1012,
#          'fpx': 555,
#          'hyc': 620,
#          'кta': 8,
#          'зшд': 122,
#          'պիա': 3,
#          'уяй': 23,
#          'んでい': 2,
#          'иє#': 13615,
#          'чys': 23,
#          'cli': 82746,
#          'zык': 29,
#          'μισ': 2,
#          'юўк': 8,
#          'рђг': 3,
#          'рxу': 4,
#          'cцe': 6,
#          'одt': 92,
#          'эчш': 7,
#          'яйм': 581,
#          'cее': 4,
#          'фаr': 4,
#          'етr': 96,
#          'lаs': 57,
#          ...})

# %%
d3g = {}
with open('3gramms-total.dict', 'rb') as fin:
    d3g = pickle.load(fin)

# %%
# prepare dataset for dssm

# %%
def fixurl(url):
    res = url
    if res.startswith('http://'):
        res = res[7:]
        
    if res.startswith('https://'):
        res = res[8:]
        
    if res.startswith('www.'):
        res = res[4:]
        
    if res.endswith('/'):
        res = res[:-1]
        
    return res

# %%
url2id = dict()
with open('./url.data', 'r') as fin:
    for line in fin:
        idx, url = line.strip().split('\t')
    
# with these fixes len(url2id) = 582092 < 582167
        url = fixurl(url)
        
#         if url in url2id:
#             print(url)
    
        url2id[url] = idx

# %%
len(url2id)
# Out:
# 582094

# %%
id2title = dict()
with open('./titles.txt', 'r') as fin:
    for line in fin:
#         print(line)
        splits = line.strip().lower().split('\t')
        if len(splits) == 1:
            id2title[splits[0]] = ''
        else:
            id2title[splits[0]] = splits[1]

# %%
len(id2title)
# Out:
# 582167

# %%
def processCL(idx, files):
    samples = []
    cur_showed = set()
    cur_clicked = set()
    cur_q = ''

    for fname, cnt in zip(files, range(len(files))):
        with bz2.BZ2File('./clicks/2017/' + fname) as fin:
            for line in fin:
                line = line.decode('utf-8').strip()
                q, showed, clicked = line.split('\t')[:3]
                q = q.split('@')[0]
            
                if q != cur_q:
                    if cur_q != '' and len(cur_clicked) != 0:
                        samples.append('\t'.join([cur_q, ','.join(cur_showed), ','.join(cur_clicked)]))
                    cur_showed.clear()
                    cur_clicked.clear()
                    cur_q = q
            
                showed = map(lambda x: url2id[x], filter(lambda x: x in url2id, map(fixurl, showed.split(','))))
                clicked = map(lambda x: url2id[x], filter(lambda x: x in url2id, map(fixurl, clicked.split(','))))
            
                cur_showed.update(showed)
                cur_clicked.update(clicked)
        
            if cur_q != '' and len(cur_clicked) != 0:
                samples.append('\t'.join([cur_q, ','.join(cur_showed), ','.join(cur_clicked)]))
            cur_showed.clear()
            cur_clicked.clear()
            cur_q = ''
        
        if (cnt + 1) % 10 == 0:
            print(idx, 'processed', cnt+1)
            
            with open('./clicks/filtered/' + str(idx) + '_' + str(cnt) + '.txt', 'w') as fout:
                fout.write('\n'.join(samples))
                samples.clear()
                
    if len(samples) != 0:
        with open('./clicks/filtered/' + str(idx) + '_' + str(cnt) + '.txt', 'w') as fout:
            fout.write('\n'.join(samples))
            samples.clear()

# %%
files = os.listdir('./clicks/2017/')
n_threads = 32
per = len(files) // n_threads + 1

# %%
Parallel(n_jobs=n_threads)(delayed(processCL)(j, files[j*per : (j+1)*per]) for j in range(n_threads))
# Out:
# 13 processed 10
# 26 processed 10
# 5 processed 10
# 24 processed 10
# 21 processed 10
# 27 processed 10
# 8 processed 10
# 11 processed 10
# 16 processed 10
# 18 processed 10
# 15 processed 10
# 10 processed 10
# 19 processed 10
# 23 processed 10
# 20 processed 10
# 2 processed 10
# 9 processed 10
# 22 processed 10
# 0 processed 10
# 25 processed 10
# 7 processed 10
# 3 processed 10
# 30 processed 10
# 14 processed 10
# 31 processed 10
# 1 processed 10
# 17 processed 10
# 6 processed 10
# 4 processed 10
# 28 processed 10
# 29 processed 10
# 26 processed 20
# 10 processed 20
# 24 processed 20
# 13 processed 20
# 23 processed 20
# 8 processed 20
# 16 processed 20
# 21 processed 20
# 12 processed 10
# 27 processed 20
# 15 processed 20
# 5 processed 20
# 20 processed 20
# 3 processed 20
# 11 processed 20
# 7 processed 20
# 13 processed 30
# 14 processed 20
# 0 processed 20
# 2 processed 20
# 19 processed 20
# 17 processed 20
# 25 processed 20
# 30 processed 20
# 22 processed 20
# 29 processed 20
# 1 processed 20
# 24 processed 30
# 4 processed 20
# 28 processed 20
# 18 processed 20
# 6 processed 20
# 31 processed 20
# 23 processed 30
# 15 processed 30
# 16 processed 30
# 26 processed 30
# 21 processed 30
# 5 processed 30
# 14 processed 30
# 10 processed 30
# 27 processed 30
# 17 processed 30
# 7 processed 30
# 19 processed 30
# 20 processed 30
# 18 processed 30
# 9 processed 20
# 8 processed 30
# 12 processed 20
# 13 processed 40
# 25 processed 30
# 0 processed 30
# 28 processed 30
# 15 processed 40
# 11 processed 30
# 1 processed 30
# 2 processed 30
# 21 processed 40
# 17 processed 40
# 16 processed 40
# 31 processed 30
# 30 processed 30
# 22 processed 30
# 12 processed 30
# 26 processed 40
# 6 processed 30
# 24 processed 40
# 19 processed 40
# 10 processed 40
# 4 processed 30
# 5 processed 40
# 7 processed 40
# 27 processed 40
# 20 processed 40
# 29 processed 30
# 13 processed 50
# 28 processed 40
# 24 processed 50
# 3 processed 30
# 14 processed 40
# 8 processed 40
# 9 processed 30
# 15 processed 50
# 4 processed 40
# 23 processed 40
# 12 processed 40
# 17 processed 50
# 16 processed 50
# 2 processed 40
# 25 processed 40
# 18 processed 40
# 7 processed 50
# 3 processed 40
# 22 processed 40
# 30 processed 40
# 27 processed 50
# 31 processed 40
# 21 processed 50
# 11 processed 40
# 24 processed 60
# 29 processed 40
# 20 processed 50
# 13 processed 60
# 19 processed 50
# 9 processed 40
# 12 processed 50
# 7 processed 60
# 5 processed 50
# 28 processed 50
# 1 processed 40
# 0 processed 40
# 16 processed 60
# 10 processed 50
# 15 processed 60
# 4 processed 50
# 6 processed 40
# 25 processed 50
# 21 processed 60
# 23 processed 50
# 26 processed 50
# 17 processed 60
# 30 processed 50
# 18 processed 50
# 2 processed 50
# 8 processed 50
# 9 processed 50
# 6 processed 50
# 3 processed 50
# 14 processed 50
# 27 processed 60
# 12 processed 60
# 20 processed 60
# 22 processed 50
# 5 processed 60
# 0 processed 50
# 4 processed 60
# 29 processed 50
# 25 processed 60
# 19 processed 60
# 1 processed 50
# 2 processed 60
# 23 processed 60
# 28 processed 60
# 26 processed 60
# 3 processed 60
# 18 processed 60
# 9 processed 60
# 8 processed 60
# 6 processed 60
# 11 processed 50
# 10 processed 60
# 30 processed 60
# 22 processed 60
# 0 processed 60
# 29 processed 60
# 14 processed 60
# 1 processed 60
# 11 processed 60
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %%
len(samples)
# Out:
# 5722

# %%
samples
# Out:
# ['игры на psp скачать\t91055,125547,287893\t125547',
#  'игры на psp скачать бесплатно\t125547\t125547',
#  'игры на psp скачать бесплатно гта 5\t565481\t565481',
#  'игры на psp скачать через торрент\t91055\t91055',
#  'игры на psp скачать exe\t432874\t432874',
#  'игры на psp торрент\t91055\t91055',
#  'игры на psp 1008 скачать бесплатно\t125547\t125547',
#  'игры на psp 2013\t450706,125547\t125547',
#  'игры на psp 2015 года\t251498\t251498',
#  'игры на psp type a\t471184\t471184',
#  'игры на psp vita скачать\t432873\t432873',
#  'игры на psp zip\t432874\t432874',
#  'игры на pspe1000 скачать\t432874\t432874',
#  'игры на ps 2 на двоих\t93868\t93868',
#  'игры на ps 2005 2014\t251555,251778,416060\t251555,251778,416060',
#  'игры на ps vita купить\t31621\t31621',
#  'игры на ps vita торрент\t432873\t432873',
#  'игры на ps1 для пк\t66546\t66546',
#  'игры на ps3 на флэшку\t251799\t251799',
#  'игры на ps3 можно ли скачать на флешку\t251799\t251799',
#  'игры на ps3 симулятор свиданий игры на рсусском языке скачать на ps3\t344418\t344418',
#  'игры на ps3 список\t251498\t251498',
#  'игры на ps3 через флешку\t251799\t251799',
#  'игры на rjvgm nth\t568581,507758,19618,506889\t506889',
#  'игры на rjvgm nth utorrent\t105661,103963\t105661',
#  'игры на rpcs3\t528808\t528808',
#  'игры на sлаbыu пк\t506889\t506889',
#  'игры на sлабые пк\t360776,540514,565483,507736,94795\t360776,540514',
#  'игры на s двоих\t478923\t478923',
#  'игры на samsung galaxy j1 характеристики\t457892\t457892',
#  'игры на sony playstation 1 на пк\t66546\t66546',
#  'игры на sony playstation 2 игры на двоих\t93868\t93868',
#  'игры на sony про выживание\t251460,477180,478519,10361,271705\t251460,478519,10361,271705',
#  'игры на steam\t45361,45359\t45361',
#  'игры на survival\t67204,109513,507805\t507805',
#  'игры на гоначных машинах гонки\t185708\t185708',
#  'игры на гонки\t185708,87400\t87400',
#  'игры на гонки мотоциклах\t520129\t520129',
#  'игры на гонки мота цыкыл\t520129\t520129',
#  'игры на гонки на пк\t290027\t290027',
#  'игры на гонках\t185708,87400\t87400',
#  'игры на гоночных машинах и прокачивать\t100657\t100657',
#  'игры на голоса в вконтакте на 100\t88622,400856\t400856',
#  'игры на голоса в вконтакте бесплатно\t400856\t400856',
#  'игры на голоса в вконтакты бесплатно\t400856\t400856',
#  'игры на геймпаде на пк через торрент\t94795\t94795',
#  'игры на гласные буквы\t500181,420312,271212,119037\t119037',
#  'игры на гласные и согласные\t426068,271212,119037\t119037',
#  'игры на гавайскую вечеринку\t112874\t112874',
#  'игры на газелях\t103271\t103271',
#  'игры на гвоих\t478923\t478923',
#  'игры на грамматический строй речи о животных\t456577\t456577',
#  'игры на гренбой\t67698\t67698',
#  'игры на грузовиках спин тирес вольво 2017 года\t507764\t507764',
#  'игры на грузовиках спин тирес вольво обыкновеном с роспуском\t507764\t507764',
#  'игры на грузовых машинах с прицепом играть и груз возить\t371084\t371084',
#  'игры на гугле\t237007,260200,18552,18535\t237007,18552,18535',
#  'игры на гугл\t237007,260200,18552\t237007,18552',
#  'игры на гугл плей\t18540,249692,31612,18535\t18535',
#  'игры на гугл плей на развитие\t68489\t68489',
#  'игры на гугл хррм\t260209,237007,493619,60167\t237007,493619',
#  'игры на гугул\t68489,18552\t18552',
#  'игры на гулянье жаворонки\t421370\t421370',
#  'игры на а дново\t478923\t478923',
#  'игры на а днаво\t478923\t478923',
#  'игры на а двоих\t478923\t478923',
#  'игры на а2\t478923\t478923',
#  'игры на адна\t478923\t478923',
#  'игры на адна во играт\t478923\t478923',
#  'игры на аднао\t478923\t478923',
#  'игры на аднало\t478923\t478923',
#  'игры на аднаво\t478923\t478923',
#  'игры на аднаво онлайн\t478923\t478923',
#  'игры на аднаво для девочек гонки\t478923\t478923',
#  'игры на аднаво для девочки\t478923\t478923',
#  'игры на аднаво для мальчиков\t478923\t478923',
#  'игры на аднаво и на двоих\t478923\t478923',
#  'игры на аднаво игрока\t478923\t478923',
#  'игры на аднаво играка\t478923\t478923',
#  'игры на аднаво играть\t478923\t478923',
#  'игры на аднаво маенкравт\t236538\t236538',
#  'игры на аднаво майнкрафт\t478923,236538\t236538',
#  'игры на аднаво минкрафт\t236538\t236538',
#  'игры на аднаво танки\t46194\t46194',
#  'игры на аднаво 1\t478923\t478923',
#  'игры на аднаво 1 бесплатно\t478923\t478923',
#  'игры на аднаво 1 для девочек\t478923\t478923',
#  'игры на аднаво 2\t478923\t478923',
#  'игры на аднаво1\t478923\t478923',
#  'игры на аднава\t478923\t478923',
#  'игры на аднаго\t478923\t478923',
#  'игры на аднво\t478923\t478923',
#  'игры на адново\t478923\t478923',
#  'игры на адного\t478923\t478923',
#  'игры на адаво\t478923\t478923',
#  'игры на адаптацию детей дошкольников\t460429\t460429',
#  'игры на адвоих\t478923\t478923',
#  'игры на адвоих для маьчиков\t478923\t478923',
#  'игры на адин\t478923\t478923',
#  'игры на адинг\t478923\t478923',
#  'игры на адроид без интернета\t411381\t411381',
#  'игры на адыного1\t478923\t478923',
#  'игры на адынаво\t478923\t478923',
#  'игры на ад на во\t478923\t478923',
#  'игры на ад наво\t478923\t478923',
#  'игры на аидин\t478923\t478923',
#  'игры на аим\t187831,138385,258042\t138385',
#  'игры на айвон для вр очков\t168613\t168613',
#  'игры на айфон 4s на русском\t21012\t21012',
#  'игры на айфон на itunes\t21012\t21012',
#  'игры на айфон в appstore\t147720,277538\t147720',
#  'игры на айфон се бесплатные в аппсторе\t147884,147720\t147720',
#  'игры на айфон эп стор\t147725,277538\t147725',
#  'игры на активизацию глагольного словаря у детей с алалией\t140841\t140841',
#  'игры на ак\t103963,255893\t103963,255893',
#  'игры на алнавоъ\t478923\t478923',
#  'игры на алавар\t244117,11140,580342,139414,358087,378440,139399,510603,244118,139413,468725,139420,384921\t139399,580342,139414,139420,139413',
#  'игры на алавар про магазины\t244117,510603,90068\t510603,90068',
#  'игры на алавар онлайн\t139399,510603,139414,139418,580342\t139399',
#  'игры на алавар бесплатно\t244119,139399,11140,510603,107178\t139399',
#  'игры на алавар жучки играть сейчас бесплатно\t580342\t580342',
#  'игры на алавар играть онлайн\t244119,139399,580342,139414,510603\t139399',
#  'игры на алавар играть без скачивания сейчас бесплатно квесты\t244119,139399,139418,510603\t139399',
#  'игры на алавар играть сейчас бесплатно\t305006,580342,139418,139414,244119,510603,521983\t244119,510603,139414,139418',
#  'игры на алавар играть сейчас бесплатно онлайн\t510603\t510603',
#  'игры на алавар играть сейчас бесплатно без скачивания\t510603,139414\t510603',
#  'игры на алавар играть сейчас бесплатно для девочек\t510603,580342\t580342',
#  'игры на алавар скачать\t244117,11140,107178,174648,139399,139413,468725,139401\t139399,139413',
#  'игры на алавар скачать бесплатно\t244117,139399,139414,378440\t244117',
#  'игры на алавар скачать и играть сейчас бесплатно\t305006,580342,174648,139414,244118,521983\t305006,139414,244118',
#  'игры на алаваре\t139399,139414,139413\t139414',
#  'игры на алдавар\t139399,139414,139413\t139399',
#  'игры на алдвоих\t478923\t478923',
#  'игры на анново 1\t478923\t478923',
#  'игры на анодроид без кеша\t457923\t457923',
#  'игры на анаво\t478923\t478923',
#  'игры на анг языке\t140563,23640\t23640',
#  'игры на английском для начинающих бесплатно\t310384\t310384',
#  'игры на андройд играть на пк\t116147,145182,522039,461229,548651,31620,67912,342629,31611\t31620,145182',
#  'игры на андройд играть бесплатно\t251469\t251469',
#  'игры на андройд которые можно играть на компютере\t116147\t116147',
#  'игры на андройд похожие на майн\t357900\t357900',
#  'игры на андройд по wifi\t31595\t31595',
#  'игры на андройд по локальной сети на двих\t125653\t125653',
#  'игры на андройд по мультиплееру\t8803\t8803',
#  'игры на андройд не онлайн\t145200\t145200',
#  'игры на андройд на пк\t116147,119347,145182,522039,461229,548651,31620,49336,11173,580531,17687\t548651',
#  'игры на андройд телифон\t540280,145202\t540280,145202',
#  'игры на андройд шадолфайт взломка\t145119\t145119',
#  'игры на андройдов как довести соседа\t285658,411378,536786\t536786,285658,411378',
#  'игры на андройдбез интернета\t411381\t411381',
#  'игры на андройт телефон\t540280,145202\t540280',
#  'игры на андройте и пк\t116147,461229,548651\t461229',
#  'игры на анкрафт\t236538\t236538',
#  'игры на анлайн маинкрафт\t236538\t236538',
#  'игры на анлроид 5 1\t549500\t549500',
#  'игры на анрдроид без интернета\t411381\t411381',
#  'игры на анроид без интерненета\t411381\t411381',
#  'игры на анройд без интернета\t411381\t411381',
#  'игры на ан\t251469,145200\t145200',
#  'игры на авалар\t244117,139418,139414,139399,510603,139413\t510603,139414,139418',
#  'игры на аваларе\t139418,139399,139414,139413\t139399',
#  'игры на август 2017\t281010\t281010',
#  'игры на авднаво\t478923\t478923',
#  'игры на агнаво\t478923\t478923',
#  'игры на аыживание\t360777,197085,356173\t197085',
#  'игры на болванках xbox 360\t68220\t68220',
#  'игры на большие трактора\t371084,567244,251883\t371084',
#  'игры на бдоих\t478923\t478923',
#  'игры на бдвомих\t478923\t478923',
#  'игры на бдврих\t478923\t478923',
#  'игры на беньги с выводом\t1338\t1338',
#  'игры на беби юзер\t46795\t46795',
#  'игры на бебиюзер поиск предметов\t46795,125847,251732,90563\t90563',
#  'игры на безударную гласную\t404453\t404453',
#  'игры на бесплатно на двоих\t478923\t478923',
#  'игры на бирже форекс\t359252\t359252',
#  'игры на биржах\t359252\t359252',
#  'игры на бмв х5 играть\t376123\t376123',
#  'игры на бна двоих\t478923\t478923',
#  'игры на баоих\t478923\t478923',
#  'игры на байках\t520129\t520129',
#  'игры на балебол\t271215,121488,244641\t244641',
#  'игры на баяках\t520129\t520129',
#  'игры на баскетбол\t251882\t251882',
#  'игры на бвоихх\t478923\t478923',
#  'игры на бвоих\t478923\t478923',
#  'игры на бвоих для девочек\t478923\t478923',
#  'игры на бвоих бесплатно\t478923\t478923',
#  'игры на бвойх\t478923\t478923',
#  'игры на бва игро ков\t478923\t478923',
#  'игры на бва игрока\t478923\t478923',
#  'игры на бваиф\t478923\t478923',
#  'игры на бваих\t478923\t478923',
#  'игры на бврих\t478923\t478923',
#  'игры на бразере\t10926,251467\t251467',
#  'игры на браузер\t10926,251467\t251467',
#  'игры на браузере\t10926,251467\t251467',
#  'игры на браузире\t251467\t251467',
#  'игры на брузере\t10926,251467\t251467',
#  'игры на бтс\t547544,358154\t547544',
#  'игры на букву в для мальчиков\t154787\t154787',
#  'игры на булдози\t416082\t416082',
#  'игры на бульдозерах на одного\t371084,95291,251883\t95291',
#  'игры на быстрость\t478923,231173\t231173',
#  'игры на быстрось\t231173\t231173',
#  'игры на быстроту печатания\t231173\t231173',
#  'игры на быстроту писания\t101247\t101247',
#  'игры на быстроту мышления\t433438\t433438',
#  'игры на в двоих\t478923\t478923',
#  'игры на в кс 1 6 jail\t506939,516842\t506939',
#  'игры на в о и х\t478923\t478923',
#  'игры на в2\t478923\t478923',
#  'игры на вопросительные слова\t18957\t18957',
#  'игры на вопросительные слова в английском языке\t18957\t18957',
#  'игры на воде для девочек\t376123,256215\t256215',
#  'игры на воде пк торент\t138401,105661\t105661',
#  'игры на водих\t478923\t478923',
#  'игры на военную тематику скачати\t118670\t118670',
#  'игры на военных вертолетах скачать бесплатно\t75322\t75322',
#  'игры на вои\t435426,478923,20387\t478923',
#  'игры на воиз\t478923\t478923',
#  'игры на воины\t117626\t117626',
#  'игры на воих\t478923\t478923',
#  'игры на воих для девочек\t478923\t478923',
#  'игры на воих игрока\t478923\t478923',
#  'игры на воих на двоих\t478923\t478923',
#  'игры на воих онлайн\t478923\t478923',
#  'игры на воих онлайн бесплатно\t478923\t478923',
#  'игры на воих ссе игры\t478923\t478923',
#  'игры на воихх\t478923\t478923',
#  'игры на воиъх\t478923\t478923',
#  'игры на войх\t478923\t478923',
#  'игры на войх броилки\t478923\t478923',
#  'игры на вотих\t478923\t478923',
#  'игры на вох\t478923\t478923',
#  'игры на вдоаих\t478923\t478923',
#  'игры на вдовоих\t478923\t478923',
#  'игры на вдових\t478923\t478923',
#  'игры на вдолих\t478923\t478923',
#  'игры на вдои\t478923\t478923',
#  'игры на вдоиx\t478923\t478923',
#  'игры на вдоиз\t478923\t478923',
#  'игры на вдоиих\t478923\t478923',
#  'игры на вдоихь\t478923\t478923',
#  'игры на вдоих\t478923\t478923',
#  'игры на вдоих онлайн\t478923\t478923',
#  'игры на вдоих для девоче къ\t478923\t478923',
#  'игры на вдоих для мальчиков\t478923\t478923',
#  'игры на вдоих бесплатно\t478923\t478923',
#  'игры на вдоих бродилки\t478923\t478923',
#  'игры на вдоиъх\t478923\t478923',
#  'игры на вдоиъ\t478923\t478923',
#  'игры на вдойх\t478923\t478923',
#  'игры на вдорих\t478923\t478923',
#  'игры на вдвоиз\t478923\t478923',
#  'игры на вдвоих\t478923\t478923',
#  'игры на вдвоихю\t478923\t478923',
#  'игры на вдвоух\t478923\t478923',
#  'игры на вдиох\t478923\t478923',
#  'игры на вдих\t478923\t478923',
#  'игры на вдмоих\t478923\t478923',
#  'игры на вдрих\t478923\t478923',
#  'игры на великах для слабых пк\t507736\t507736',
#  'игры на великах мальчик сабирает деньги\t478923\t478923',
#  'игры на вертолетах\t75322\t75322',
#  'игры на вертолетах скачать\t75322\t75322',
#  'игры на верталетах\t75322\t75322',
#  'игры на веселые перидача\t448563,124442\t124442',
#  'игры на весь экран басткетбол\t478924\t478924',
#  'игры на весь экран гтэа\t195885,263172\t195885',
#  'игры на вечеринках днях рождения\t102860\t102860',
#  'игры на виживання\t197085,250337,95287,507805\t197085,507805',
#  'игры на виживання по сети\t360777,100830,197085\t360777,197085',
#  'игры на виживаные\t360777,197085,507805\t197085,507805',
#  'игры на виживаныэ\t360777,197085,356173\t197085',
#  'игры на виживаніє\t360777,197085,356173,507805\t197085',
#  'игры на вижывние для слабых пк\t545026,388746\t545026',
#  'игры на вижывание\t360777,197085,507805\t197085',
#  'игры на визиване\t360777,197085,356173\t197085',
#  'игры на вих\t478923,276806,58595\t478923',
#  'игры на вк\t49948,67989,253426\t49948',
#  'игры на вк блок страйк\t251706\t251706',
#  'игры на вк верность\t470558\t470558',
#  'игры на влих\t478923\t478923',
#  'игры на вмщшч\t478923\t478923',
#  'игры на внимание 10 лет\t328508\t328508',
#  'игры на внимание 9 10 лет\t328508\t328508',
#  'игры на внимание для 10 лет\t328508\t328508',
#  'игры на внимание для детей 10 лет\t328508\t328508',
#  'игры на внимание для детей 6 7 лет\t328507\t328507',
#  'игры на внимание для детей 9 10 лет\t328508\t328508',
#  'игры на внимание для школьников\t328508\t328508',
#  'игры на внимание для школьников 12 лет\t328508\t328508',
#  'игры на внимание и память во второй младшей группе\t214613\t214613',
#  'игры на внимание скачать на пк\t344601,139415\t139415',
#  'игры на внимание с зашифрованными словами\t251887\t251887',
#  'игры на внимания для детей 10 лет\t328508\t328508',
#  'игры на внимательность и логику\t311587\t311587',
#  'игры на ваих\t478923\t478923',
#  'игры на вайих\t478923\t478923',
#  'игры на ввоих\t478923\t478923',
#  'игры на ввоиъх\t478923\t478923',
#  'игры на все пк скачать торент\t255893,103963,507758\t507758',
#  'игры на все времена\t251777,75315\t251777,75315',
#  'игры на все времена на пк\t251777,17866\t17866',
#  'игры на все умножения\t115466\t115466',
#  'игры на всех машинах\t185708\t185708',
#  'игры на всех машинах проходить уровне стрылять\t251596\t251596',
#  'игры на встроенную видеокарту\t461350,416017\t416017',
#  'игры на встречу года петуха\t265369,142885,7315,25514\t265369',
#  'игры на всё команду секс\t23282,133423\t133423',
#  'игры на вфоих\t478923\t478923',
#  'игры на вчоих\t478923\t478923',
#  'игры на выоих\t478923\t478923',
#  'игры на вывод денег\t27236,1338,1339\t27236,1338,1339',
#  'игры на вывод денег на яндекс деньги без вложений\t543851,1339\t1339',
#  'игры на вывод денег без вложений\t1338,1339\t1338,1339',
#  'игры на вывод денег без вложений на яндекс кошелек\t543851\t543851',
#  'игры на вывод реала\t1339\t1339',
#  'игры на вывод средств\t1339\t1339',
#  'игры на выдивание\t360777,197085,507805\t360777',
#  'игры на выжавание\t197085,356173,507805\t197085',
#  'игры на выжавание 3д\t401154,197085\t401154',
#  'игры на выжвание\t197085,356173,507805\t197085,507805',
#  'игры на выжвание на острове\t360777,272035\t360777',
#  'игры на выжвание скачать\t95287,507805\t95287,507805',
#  'игры на выжвание с видом сверху\t271228,356173\t356173',
#  'игры на выжвания скачать\t493762,95287,507805\t493762,507805',
#  'игры на выжвывание\t197085,356173,507805\t197085',
#  'игры на выжеване скачать\t250337,95287,507805\t507805',
#  'игры на выжевание\t360777,545026,197085,356173,507805\t360777,197085',
#  'игры на выжевание по\t401154,109513\t109513',
#  'игры на выжевание по сети\t65793,360777,197085,109513,507805\t109513',
#  'игры на выжевание на пк\t545026,197085,356173,95287,507805\t507805',
#  'игры на выжевание на ноутбук\t356173,507805\t356173,507805',
#  'игры на выжевание на остраве\t360777,279329,272035,507805\t360777,272035,507805',
#  'игры на выжевание для слабогопк\t360776,497003,388746\t360776',
#  'игры на выжевание с большим открытым миром на пк\t168074\t168074',
#  'игры на выжевание скачать\t493762,250337,95287,507805\t95287,507805',
#  'игры на выжевание скачать через торрент\t101596,94653,250337,95287,507805\t101596',
#  'игры на выжевание топ\t388746,109513,356173,360777,554622,360784\t360777',
#  'игры на выжевание торент на слабый пк\t250337,95287\t250337',
#  'игры на выжевания\t197085,95287,360777,17986,283434,545026,507805\t360777',
#  'игры на выжевания на острове\t272035,507805\t507805',
#  'игры на выжеваня\t197085,507805\t197085',
#  'игры на выжживание\t360777,197085,507805\t197085',
#  'игры на выжи вание\t360777,197085,507805\t197085',
#  'игры на выжимание\t360777,197085,356173,507805\t360777',
#  'игры на выжиание\t545026,197085,507805\t545026',
#  'игры на выживние\t197085,356173,507805\t197085',
#  'игры на выживние онлайн\t65793\t65793',
#  'игры на выживние слабый пк\t545026,250337\t250337',
#  'игры на выживоние на пк\t197085,283434,95287,507805\t95287',
#  'игры на выжива\t360777,244694,197085\t197085',
#  'игры на выживаание\t197085,507805\t197085',
#  'игры на выживааание\t197085,356173\t197085',
#  'игры на выживаение со стоителствои и крафтом\t197085\t197085',
#  'игры на выживает скачать\t250337,95287,507805\t507805',
#  'игры на выживанеия\t197085,507805\t197085',
#  'игры на выживане\t360777,30103,197085,356173,507805\t197085',
#  'игры на выживане офлайн\t507805,237602,197085,67204\t197085',
#  'игры на выживание\t388746,95287,271705,45366,17986,545026,250337,507805,562497,66231,244694,458000,197085,360777,96004,554622,94653,65793,30103,290022,272035,109513,356173,67204,63205,283434\t458000,244694,197085,290022,388746,356173,95287,271705,45366,360777,17986,94653,30103,545026,507805',
#  'игры на выживание песочница\t197085,507805\t197085',
#  'игры на выживание пк\t458000,237602,197085,290022,279329,356173,95287,271705,360770,360777,17986,554622,283434,540515,94653,271228,545026,250337,507805\t237602,197085,95287,360777,283434,279329,94653,271228,545026,507805',
#  'игры на выживание по локальной сети на слабые пк\t360776,540514\t360776',
#  'игры на выживание по сети\t415938,197085,109513,356173,360770,45366,360777,17986,127949,65793,545026,250337,558713,507805\t197085,109513,360777,65793,250337,507805',
#  'игры на выживание по сети 3в\t360777,401154\t401154',
#  'игры на выживание по сети без платно\t66313\t66313',
#  'игры на выживание по сети белплатно\t65793,109513\t109513',
#  'игры на выживание по сети для средних пк\t360776,251460,540514,80551,197085\t360776,251460,197085',
#  'игры на выживание по сети играть\t197085,356173,109513\t356173',
#  'игры на выживание по сети на пк\t360777,545026,197085,360770\t197085',
#  'игры на выживание по сети с другом\t360777,197085,109513\t360777',
#  'игры на выживание по сети скачать\t360777,271221,197085,109513,507805\t507805',
#  'игры на выживание на слабый пк\t540514,237602,388746,360776,95287,497003,545026,507805\t545026,388746,507805',
#  'игры на выживание на слабый и старый пк\t360776,540514,497003,388746\t388746',
#  'игры на выживание название скачять\t95287\t95287',
#  'игры на выживание не онлайн\t65793\t65793',
#  'игры на выживание одиночная игра\t356173,545026,290022,360770\t360770',
#  'игры на выживание одиночный режим\t356173\t356173',
#  'игры на выживание одиночка топ\t356173,63205\t356173',
#  'игры на выживание олайн на пк торрент\t101596,250337,95287\t95287',
#  'игры на выживание онлаин\t65793\t65793',
#  'игры на выживание онлай\t65793,197085,360770\t65793',
#  'игры на выживание онлайин\t65793,244694\t65793',
#  'игры на выживание онлайнр\t65793\t65793',
#  'игры на выживание онлайн\t244694,66313,179073,197085,360770,45366,360777,96004,65793,272056,545026,507805\t65793,66313,360770',
#  'игры на выживание онлайн crfxfnm\t65793,507805\t507805',
#  'игры на выживание онлайн по сети\t65793,360777,197085,109513\t360777',
#  'игры на выживание онлайн клиентские\t65793\t65793',
#  'игры на выживание онлайн клиентские на слабый комп\t360776,545026,497003\t360776,497003',
#  'игры на выживание онлайн на пк через торрент\t101596,94795,507805\t94795',
#  'игры на выживание онлайн на острове 3д\t401154\t401154',
#  'игры на выживание онлайн на слабый пк\t388746,497003\t388746,497003',
#  'игры на выживание онлайн на pc\t65793,545026,197085,250337,360770\t65793',
#  'игры на выживание онлайн бесплатно\t65793,244694\t65793',
#  'игры на выживание онлайн скачать\t197085,356173,554622,65793,94653,507805\t554622',
#  'игры на выживание онлайнl на пк через торрент\t250337,95287\t250337',
#  'игры на выживание от первого лица\t101596,30103,545026,271705,95287\t271705',
#  'игры на выживание офлайн\t237602,30103,545026,197085\t237602',
#  'игры на выживание оффлайн\t237602,17986,197085,356173,67204\t197085',
#  'игры на выживание андроид\t145206,11178,127949,27056,507805\t27056',
#  'игры на выживание бегать и стрелять\t251596\t251596',
#  'игры на выживание браузерные\t360777,197085\t360777',
#  'игры на выживание в природе на пк\t341322,545026\t341322',
#  'игры на выживание в природе на русском языке для пк\t101596,250337,95287,507805\t250337,95287',
#  'игры на выживание в открытом мире\t415938,197085,356173,95287,360777,17986,554622,545026,250337,507805\t360777,197085,507805',
#  'игры на выживание в открытом мире где каждый патрон на счету и можно ездить на транспорте\t545026\t545026',
#  'игры на выживание в открытом мире интернет\t360777,197085,283434,507805\t360777',
#  'игры на выживание в открытом мире на пк\t237602,197085,290022,95287,360777,251460,17986,283434,545026,507805\t360777,197085,507805',
#  'игры на выживание в открытом мире на пк онлайн\t400752,360797,545026,360770\t360797',
#  'игры на выживание в открытом мире на пк скачать торрент\t94653,250337,101596,507805\t250337',
#  'игры на выживание в открытом мире на пк 2016\t168074,507805\t168074',
#  'игры на выживание в офлайне\t197085,250337,95287,360777,290021,272056,545026,67204\t360777,250337,95287',
#  'игры на выживание в вк\t11178,197085,356173\t197085,356173',
#  'игры на выживание в защитном костюме\t30103\t30103',
#  'игры на выживание в зимний период 2003 года\t545026\t545026',
#  'игры на выживание в зомби\t237602,271228\t271228',
#  'игры на выживание в кооперативе\t197085\t197085',
#  'игры на выживание в лесах\t356173\t356173',
#  'игры на выживание в лесу\t458000,415938,290022,356173,17986,283434,30103,545026,507805\t283434,356173',
#  'игры на выживание в лесу пк\t290022\t290022',
#  'игры на выживание в лесу без монстров как в реальной жизни графика\t545026\t545026',
#  'игры на выживание в майнкрафте\t236538\t236538',
#  'игры на выживание в сети\t197085,109513\t109513',
#  'игры на выживание в суровых условиях пк\t545026\t545026',
#  'игры на выживание в стиме\t197085,356173,558713,507805\t197085,558713',
#  'игры на выживание в тропиках\t272056,493762,283434,540515\t493762,283434',
#  'игры на выживание вдвоем\t127949,290022,558713\t558713',
#  'игры на выживание где есть волны чем больше волна тем сложнее выживать\t545026\t545026',
#  'игры на выживание где надо управлять группой выживших\t558713\t558713',
#  'игры на выживание где нужно искать лут\t30103\t30103',
#  'игры на выживание где нужно строить\t360777,356173\t360777',
#  'игры на выживание где сохраняется игра\t545026\t545026',
#  'игры на выживание для windows xp 1gb оперативки\t540514,79962\t79962',
#  'игры на выживание для xp\t250337,356173\t356173',
#  'игры на выживание для очень слабых пк\t360776,540514,497003,388746\t497003,388746',
#  'игры на выживание для пк\t416065,197085,388746,65105,356173,95287,497003,283434,554622,94653,545026,250337,507805\t416065,197085,95287,545026,250337,507805',
#  'игры на выживание для девочек\t272056,478923,507805\t272056',
#  'игры на выживание для детей\t272056,197085\t272056',
#  'игры на выживание для андроид\t388090,147729,145206,127949,27056\t127949,27056',
#  'игры на выживание для андройд\t145206,27056\t145206,27056',
#  'игры на выживание для слабого и среднего пк\t360776,388746,94795\t388746',
#  'игры на выживание для слабыж пк\t360776,388746\t388746',
#  'игры на выживание для слабых пк\t237602,540514,388746,360776,95287,360770,497003,30103,545026\t237602,388746,360776,497003,30103,545026',
#  'игры на выживание для слабых пк виндовс 7\t540514\t540514',
#  'игры на выживание для слабых пк скачать\t497003,388746\t497003',
#  'игры на выживание для слабых пк стрелялки\t540514,94795\t94795',
#  'игры на выживание для слабых нубаф\t138401,497003,388746,545024\t138401,497003,388746',
#  'игры на выживание дл девочек\t272056\t272056',
#  'игры на выживание дял слабы пк\t545026,388746\t388746',
#  'игры на выживание зимой на пк\t101596,250337,283434\t101596,250337',
#  'игры на выживание зомби\t237602,271228\t237602',
#  'игры на выживание зомби апокалипсис мультиплеер для слабых пк\t237602,545026\t237602',
#  'игры на выживание зомби на пк\t237602,271228,360775\t237602',
#  'игры на выживание и на прокачивания на пк\t540514,415938\t540514',
#  'игры на выживание и зомби\t237602\t237602',
#  'игры на выживание и строительства\t415938,197085,356173,94653,80394,507805\t94653,415938,197085,356173,507805',
#  'игры на выживание и стройку на пк\t251460,197085,283434\t197085',
#  'игры на выживание играть\t272056,244694,507805\t272056',
#  'игры на выживание играть онлайн\t65793,272056,179073\t179073',
#  'игры на выживание играть онлайн бесплатно\t65793,272056,244694,401154,507805\t65793,244694,507805',
#  'игры на выживание кооператив\t197085\t197085',
#  'игры на выживание кооперативные\t197085\t197085',
#  'игры на выживание крафтом строительством на пк\t507805\t507805',
#  'игры на выживание лучшие\t356173,360777,554622,109513\t554622',
#  'игры на выживание ммо\t360777\t360777',
#  'игры на выживание мультиплеер скачать игры торент\t250337,95287\t250337',
#  'игры на выживание с пк\t197085,507805\t507805',
#  'игры на выживание с постройкой\t360777,66313,197085,545026\t360777,197085',
#  'игры на выживание с постройкой базы\t415938,197085,558713\t415938',
#  'игры на выживание с постройками\t360777,415938,545026,197085,507805\t197085',
#  'игры на выживание с открытым миром\t17986,415938,545026,197085,507805\t415938',
#  'игры на выживание с открытым миром на пк\t415938,197085,17986,283434,545026,507805\t197085',
#  'игры на выживание с открытым миром на пк торент\t250337,95287\t250337',
#  'игры на выживание с открытым миром сккачать\t94653,197085,507805\t507805',
#  'игры на выживание с взаимодействием\t94653,168074\t168074',
#  'игры на выживание с группами\t65793\t65793',
#  'игры на выживание с другом\t360777,197085,356173,45366\t45366',
#  'игры на выживание с друзьями\t360777,290904,356173\t360777',
#  'игры на выживание с зомби\t237602,271228\t237602,271228',
#  'игры на выживание с зомби для слаюых пк\t237602,545026\t237602',
#  'игры на выживание с зомби и постройками скачать на слабые пк\t497003,388746,250337,95287,279329\t497003',
#  'игры на выживание с зомби на пк\t360775,237602,271228,499814\t271228,499814',
#  'игры на выживание с зомби с оружием\t237602,360775\t237602',
#  'игры на выживание с кооперативом для слабых пк\t360776,497003\t360776',
#  'игры на выживание с кооп\t197085\t197085',
#  'игры на выживание с крафтом\t415938,197085,356173,360770,360777,30103,545026,250337,507805\t197085,507805',
#  'игры на выживание с крафтом на пк оффлайн\t545026,250337,95287\t95287',
#  'игры на выживание с крафтом с зомби с оружием\t356173,237602,271228,360777,360775\t237602',
#  'игры на выживание с крафтингом которые можно купить на стим\t45366\t45366',
#  'игры на выживание с лутом\t30103,67204\t67204',
#  'игры на выживание с мультиплеером\t197085,109513,356173,360777,127949,65793,250337,507805\t65793,127949,197085,109513,507805',
#  'игры на выживание с мультиплеером на пк\t65793,197085,95287\t197085',
#  'игры на выживание с хорошей г\t168074,67204\t67204',
#  'игры на выживание с хорошей графикой\t360777,17986,545026,127949,356173\t360777,356173',
#  'игры на выживание с читами\t401154\t401154',
#  'игры на выживание сетевые видео 2027 году\t360777,271228,17986\t271228',
#  'игры на выживание сетевые видио\t65793,197085,109513\t65793',
#  'игры на выживание сетивые\t360777,197085,109513,95287\t360777',
#  'игры на выживание слабый пк\t101596,545026,95287\t95287',
#  'игры на выживание скатать\t94653,279329,95287,507805\t507805',
#  'игры на выживание скачать\t197085,101596,356173,95287,360770,493762,554622,279329,94653,250337,507805\t197085,95287,493762,279329,94653,250337,507805',
#  'игры на выживание скачать пк\t94653,95287,507805\t507805',
#  'игры на выживание скачать на комютер\t493762,95287,279329\t279329',
#  'игры на выживание скачать на кампютер\t250337,507805\t250337',
#  'игры на выживание скачать на пк\t341322,356173,95287,94653,250337,507805\t94653,95287',
#  'игры на выживание скачать на отрове бесплатно\t250337\t250337',
#  'игры на выживание скачать новые\t493762\t493762',
#  'игры на выживание скачать бесплатно\t101596,279329,250337,95287,507805\t101596,95287,507805',
#  'игры на выживание скачать торен\t101596,250337,95287,507805\t250337,95287',
#  'игры на выживание скачать торрент\t101596,95287,279329,94653,250337,507805\t94653,250337,101596,95287,507805',
#  'игры на выживание скачать торрент на пк\t101596,250337,95287\t250337',
#  'игры на выживание скачать торрент бесплатно на pc\t94653,95287,507805\t95287',
#  'игры на выживание скачать тор рент\t94653,279329,95287,507805\t95287,507805',
#  'игры на выживание скачать через торент\t101596,94653,250337,95287,507805\t101596',
#  'игры на выживание скачать через торрент\t101596,94653,250337,95287,507805\t101596,95287,507805',
#  'игры на выживание скачть\t95287,507805\t507805',
#  'игры на выживание список\t271705,251460,554622,271228,545026,10361,507805\t545026,554622,271705',
#  'игры на выживание список пк\t168074,545026\t168074',
#  'игры на выживание со строительством\t197085,356173,507805\t356173',
#  'игры на выживание стим\t65200,197085,356173\t65200,197085',
#  'игры на выживание строительство\t236538,197085,356173\t197085',
#  'игры на выживание страительство скачать\t94653,197085,507805\t507805',
#  'игры на выживание стратегии\t360777\t360777',
#  'игры на выживание стратегии на пк\t540514,545026,250337,95287\t545026,250337',
#  'игры на выживание стратегии топ\t360777,478519\t360777',
#  'игры на выживание стратегия для слабых пк\t360776,540514,545026,497003\t540514',
#  'игры на выживание стрелялки в зомби\t271228,251825\t271228',
#  'игры на выживание стрелялки скачать\t360770,95287\t95287',
#  'игры на выживание типа майнкрафт\t236538\t236538',
#  'игры на выживание топовые\t360777,388746,554622,109513,197085\t360777,109513',
#  'игры на выживание топ\t458000,388746,109513,356173,360777,17986,554622,540515,360784\t360777,17986,356173,109513',
#  'игры на выживание топ 10\t458000,415938,68486,197085,109513,356173,360777,17986,283434,540515,251869,30103,558713,507805\t360777,558713',
#  'игры на выживание топ лучшие\t388746,109513,360777,554622,30103,67204\t360777,109513',
#  'игры на выживание топ на пк\t360777,168074,545026,388746,540515\t388746',
#  'игры на выживание торент\t94653,279329,250337,95287,507805\t507805',
#  'игры на выживание торэнт\t94653,279329,507805\t279329',
#  'игры на выживание торрент\t101596,95287,279329,94653,250337,507805\t250337,507805',
#  'игры на выживание через интернет\t94653,197085,507805\t197085',
#  'игры на выживание через хамачи\t65793,360777,197085,109513\t65793',
#  'игры на выживание 3d\t401154\t401154',
#  'игры на выживание 3д\t401154\t401154',
#  'игры на выживание 3д играть\t401154\t401154',
#  'игры на выживание 3д скачать на компьютер\t401154,356173\t401154',
#  'игры на выживание 3д с оружием\t401154\t401154',
#  'игры на выживание 3д с едой с аружыем играть\t401154\t401154',
#  'игры на выживание 2005\t237602,271228,356173,95287\t356173',
#  'игры на выживание 2005 2017\t250337,507805\t250337,507805',
#  'игры на выживание 2010\t251460,290022\t251460,290022',
#  'игры на выживание 2010 скачать\t94653,493762\t493762',
#  'игры на выживание 2012\t250337,290022\t250337,290022',
#  'игры на выживание 2014\t554622\t554622',
#  'игры на выживание 2016\t478519,197085,507805\t478519,507805',
#  ...]

# %%
arr = np.array([10, 11, 32, 14, 12])

# %%
np.random.permutation(arr)[0:4]
# Out:
# array([10, 12, 32, 11])
